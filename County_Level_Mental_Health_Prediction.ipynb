# %% [markdown]
# ##**TOTAL = 45 / 45**
#
# <b>
#
# Introduction - 5
#
# Data Descrtiption and Summary Statistics - 5
#
# Data Visualizations - 5
#
# Model Selection and Execution - 5
#
# Model Evaluation - 5
#
# Model Visualization - 5
#
# Model Discussion - 5
#
# Conclusions - 5
#
# Presentation - 5
#
# Outstanding work!  I only have a few very minor suggestions below which mostly have to do with making visualizations more effective.  The only conceptual comment I have is to be careful about feature importance interpretaions.  As we discussed in class, covariance in your feature set can lead to importances being split across features that are correlated or anti-correlated.
#
# *MORE IN LINE COMMENTS BELOW (SEARCH FOR "GD:")*
#
# ---
#
# </b>

# %% [markdown]
# # ***MLPP25 // Mental Health Indicators in the United States***
#
# <big>Gayathri Emuru</big>
#
# <i>May 15, 2025</i>
#
# ---
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Image source link](https://www.vecteezy.com/vector-art/3328045-blue-outline-usa-map-on-white-background-vector-illustration)

# %% [markdown]
# Presentation Slides Link: [Mental Health Indicators in United States](https://docs.google.com/presentation/d/1umqYkwOEDONAtuTzyw-TfNdAV6INPiv8/edit?usp=sharing&ouid=102986056972866974284&rtpof=true&sd=true)

# %% [markdown]
# ##***Index***
#
# ***1.   Introduction***
#   *   Background
#   *   Literature Review
#   *   Problem Statement
#
# ***2.   Data Description***
#   *   Data Collection & Sources
#   *   Data Dictionary
#   *   Data Cleaning(Handling Missing Values, Duplicates)
#   *   Merging Datasets
#   *   Feature Engineering & Preprocessing
#
# ***3.   Summary Statistics and Visualizations***
#   *   Descriptive Statistics
#   *   Visualizations
#
# ***4.   Methods and Results***
#   *   Regression Model
#   *   Classification Model
#
# ***5.   Conclusion***

# %% [markdown]
# ##**County-Level Socioeconomic Risk Profiles and Mental Health Outcomes in the United States 2023**

# %% [markdown]
# ## **I. Introduction**

# %% [markdown]
# ### Background
#
# Mental health disorders are a significant public health concern in the United States, affecting a substantial portion of the population. According to the [National Institute of Mental Health](https://www.nimh.nih.gov/health/statistics/mental-illness) estimation that more than one in five U.S adults live with a mental illness (59.3 million in 2022) and  with the highest prevalence of Serious Mental Illness (SMI) is among the young adults aged between 18-25 years(11.6%) compared to adults aged 26-49 years(7.6%) and aged 50 and older (3.0%). Yet according to the [SAMHSA](https://www.samhsa.gov/data/sites/default/files/reports/rpt42731/2022-nsduh-main-highlights.pdf) in 2022, 29.3 million adults untreated of those, 26.6% (about 7.6 million people)reported an unmet need for care.
#
# Adolescents face similar challenges. The [CDC's 2023 Youth Risk Behavior Survey](https://www.cdc.gov/mmwr/volumes/73/su/su7304a9.htm)  indicate that 39.7% of high school students experienced persistent feelings of sadness  and hopelessness. Notably, 52.6% of female students reported such feelings compared to the 27.7% of male students. Additionally 20.4% of students seriously considered attempting suicide and 9.5% attempted suicide in the past year 2022.
#
# According to the [National Center for Health Statistics CDC Suicide and Homicide Death Rates](https://www.cdc.gov/nchs/products/databriefs/db471.htm) between 2007 and 2021, the suicide rate among individuals aged 10-24 increased by 62% from 6.8 to 11.0 deaths per 100,000.
#
#
# According to the [JAMA Health Forum](https://jamanetwork.com/journals/jama-health-forum/fullarticle/2816755), despite the growing need, access to mental health care is deeply uneven. More than half of U.S. counties lack a single psychiatrist mainly in the rural areas. Moreover, child and adolescent psychiatrists remain critically scarce, intensifying disparities among youth. Moreover, Insurance related barriers further restrict access.  Efforts to improve access include reducing administrative burdens incresing Medicaid reimbursement rates. However, the private pay market continues to dominate leaving many without necessary mental health care.
#
#
#
#  The [Centers for Disease Control and Prevention(CDC)](https://www.cdc.gov/mental-health/about/index.html) and other public health initiatives are focusing on primary prevention strategies to address mental health challenges. The CDC give more importance for promoting positive mental health and preventing mental health conditions before they develop. The approach identifies and addressing the underlying causes of mental distress while enhancing protective factors within communities.
#
#  According to the [Office of Disease prevention and Health Promotion](https://odphp.health.gov/healthypeople/objectives-and-data/browse-objectives/mental-health-and-mental-disorders) by 2030, the healthy people objective is to improve mental health outcomes through prevention, screening, assessment and treatment of mental disorders.These objectives aim is to reduce the burden of mental health conditions and enhance the quality of life for affected individuals.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Image Source link: [nami(National Alliance on Mental Illness](https://www.nami.org/about-mental-illness/mental-health-by-the-numbers/)

# %% [markdown]
# ###Literature Review
#
#
#
# *   **county-level Mental Health Assessment**
#
#    The [CDC PLACES, 2021](https://www.cdc.gov/places/methodology/index.html) project applies multilevel regression and poststratification (MRP) to BRFSS data, generating county-level estimates of method to generate estimates of behavioral and mental health indicators for adults aged 18 and older. These estimates help policymakers and researchers assess geographical disparities in mental health conditions.
#
#
# *  **Predictive Modeling of Depression in Hypertensive Populations**
#
#   The PLOS ONE study[Machine learning-based predictive modeling of depression in hypertensive populations](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0272330) developed classification models using six ML algorithms (ANN, Random Forest, AdaBoost, stochastic gradient boosting, XGBoost, and SVM) on individual-level NHANES data (n = 8,628; 11.3% depressed defined by PHQ-9 ≥ 10). The best model (ANN) achieved an AUC of 0.813, and the most influential predictors were the family-income-to-poverty ratio, triglyceride level, white blood cell count, age, sleep disorder status, arthritis diagnosis, hemoglobin level, marital status, and education level

# %% [markdown]
# ###Problem Statement
#
# From the above background sources it is evident that, millions of Americans struggle with poor mental health due to socio economic challenges such as low-income, unemployment, low education levels, healthcare shortages, financial constraints. Access to treatment remains unequal, with vulnerable populations facing the greatest obstacles.
#
#
#  In this project,
#
# *   Identify the key socio-economic predictors that contribute to county poor mental health.
# *   Develop machine learning models to forecast the average number of poor mental health days per county based on socio-economic factors, and
# classify whether lifestyle changes predict shifts in poor mental health days.
# *   Provide data-driven insights to support public health initiatives and improve mental health resource allocation.

# %% [markdown]
# ---

# %% [markdown]
# ## **II. Data Description**

# %% [markdown]
# ###Data Collection & Sources
#
# The data collection for mental health indicators in United States study is challenging because mental health indicators are not consistently available in census data, requiring multiple sources to merge relevant information. The [National Institute of Mental Health](https://www.nimh.nih.gov/health/statistics/mental-illness)(NIMH) reports that mental illness affect over 59.3 million U.S. adults, but county-level data is often missing from standardized data sets.
#
# The 2020 [National Survey on Drug Use and Health](https://www.samhsa.gov/data/data-we-collect/nsduh-national-survey-drug-use-and-health/national-releases/2020)(NSDUH) cautions that COVID-19-era data are affected by survey-disruption and behavior-change biases, and therefore recommends against using those estimates for longitudinal or county-level analyses. Accordingly, we do not include 2020 NSDUH figures in our modeling.
#
#
# In this project, we aim to identify the key socio-economic predictors contributing to poor mental health days. To achieve this, we collected and integrated county-level demographic and socio-economic data from multiple sources including the USDA Population Center and County Health Rankings & Roadmaps.
#
# The data from [USDA's County-Level Population Center](https://www.ers.usda.gov/data-products/county-level-data-sets/county-level-data-sets-download-data) is extracted from the U.S Census Bureau's Population Estimates Program, which internally captures the  demographic trends such as education levels, poverty rates, unemployment across the U.S. counties.
#
# The [County Health Rankings & Roadmaps](https://www.google.com/url?q=https%3A%2F%2Fwww.countyhealthrankings.org%2Fhealth-data%2Fmethodology-and-sources%2Fdata-documentation) framework provides standardized measures for social and economic factors(e.g; smoking rates, exercise opportunities,availability of mental health providers) that are linked to the mental health well being. For reference [ 2023 Documentation link](https://www.countyhealthrankings.org/sites/default/files/media/document/2023%20CHRR%20Technical%20Document.pdf)

# %% [markdown]
# #### Data Analytics
#
# *   [Data Set Link](https://www.countyhealthrankings.org/sites/default/files/media/document/analytic_data2023_0.csv)
#
# *   Owner of the data is County Health Rankings & Roadmaps (CHR&R), a program of the University of Wisconsin Population Health Institute (UWPHI). The program has been supported by the Robert Wood Johnson Foundation (RWJF) since 2008.
#
# *   CHR&R collects data from various sources including government and institutional data sets. These sources are like survey records, administractive records and analytical process.
#
# *   The date is for 2023 year based on fips codes every county
#
# *   The data set consists of poor mental health days measures and socio economic features of total 720  columns and 3194 rows
#
# *   This data give insights about the socio economic factors like unemployment, poor mental health days, median household incomes,  income in equality, race measures. this helps to get insights which socio economic factor influencing the mental health on count level
#
# * [Documentation Link](https://www.countyhealthrankings.org/sites/default/files/media/document/2023%20CHRR%20Technical%20Document.pdf)

# %% [markdown]
# **Data Dictionary for 2023 Analytics Dataset**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this dataset all the variable values are continous values. According to the [2023 Documentation](https://www.google.com/url?q=https%3A%2F%2Fwww.countyhealthrankings.org%2Fsites%2Fdefault%2Ffiles%2Fmedia%2Fdocument%2F2023%2520CHRR%2520Technical%2520Document.pdf) Methods section the data is collected,review and prepare data from dozens of data sources across the
# U.S.  Then, the team follows these steps:
# 1. Assign weights: First, counties are ranked within each of the 50 U.S. states using measures that are assigned
# relative weights within the Health Outcomes and Health Factors Areas.
# 2. Calculate Z-scores: Next, measures are standardized within each state using a Z-score.
# 3. Create composite scores: The ranks are then calculated based on weighted sums of the standardized measures
# within each state—we call these weighted sums a composite score. The county with the lowest composite
# score (best health) gets a rank of #1 for that state and the county with the highest composite score (worst
# health) is assigned the lowest rank.
# 4. Calculate Ranks and quartiles: After the Ranks are calculated, CHR&R calculates quartiles. Counties are
# grouped into four equally sized groups (quartiles) from Least Healthy to Healthiest (Lowest 0-25%, Lower 25
# 50%, Higher 50-75%, and Healthiest 75-100%) within each state.
# 5. Create supplemental tools: Lastly, we calculate trend and Areas to Explore and Areas of Strength.

# %% [markdown]
# ####Education Affirmations
#
# * [Data set Link](https://www.google.com/url?q=https%3A%2F%2Fwww.ers.usda.gov%2Fdata-products%2Fcounty-level-data-sets%2Fcounty-level-data-sets-download-data)
#
# * Owner of the data is from U.S. Census Bureau (Decennial Census and American Community Survey)
#
# * The data collected from decennial censuses (1970-2000) and 5-year estimates from the American Community Survey (2008-12 and 2019-23)
#
# * The date is for 1970 to 2023 year for the United States county level.
#
# * the data set consists of fips code, attributes like bachelors_degree_or_higher, no_school_diploma, Percent of adults who are not high school graduates etc., and values.
#
# *   This data give insights about the education attaintment a key socio economic factor infuencing the mental health outcomes including mental health.
#
# *  [Documentation Link](https://www.ers.usda.gov/data-products/county-level-data-sets/documentation)

# %% [markdown]
# **Data Dictionary for Education Affirmations 2023 data file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Poverty Data
#
#
#
# * [Data set Link](https://www.google.com/url?q=https%3A%2F%2Fwww.ers.usda.gov%2Fdata-products%2Fcounty-level-data-sets%2Fcounty-level-data-sets-download-data)
#
# * Owner of the data is from U.S. Census Bureau's Small Area Income and Poverty Estimate (SAIPE) program.
#
# * The data collected from various sources including the surveys and administrative records
#
# * The date is for 2023 year for the United States county level.
#
# * the data set consists of fips code, attributes like POVALL_2023 for total count of individuals in year 2023, CI90LBALL_2023 as lower bound of the 90% confidence interval, CI90UBALL_2023 upper bound of the 90% confidence interval,PCTPOVALL_2023 percentage of poverty population,  CI90LBALLP_2023 lower bound of the 90% confidence intervals and those values.
#
# *   This data give insights about the poverty a key socio economic factor infuencing the mental health outcomes including mental health.
#
# *  [Documentation Link](https://www.ers.usda.gov/data-products/county-level-data-sets/documentation)

# %% [markdown]
# **Data Dictionary for Poverty 2023 data file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Population data
#
# * [Data set Link](https://www.google.com/url?q=https%3A%2F%2Fwww.ers.usda.gov%2Fdata-products%2Fcounty-level-data-sets%2Fcounty-level-data-sets-download-data)
#
# * Owner of the data is from U.S. Census Bureau, Population Estimates Program.
#
# * The data collected from intercensal tables (1990-2010) and vintage population estimates (2020, 2023).
#
# * The date is from 1990 and 2010 year for all the United States county level.
#
# * the data set consists of population estimation of data for each year and those values.
#
# *   This data give insights about the demographic cotests of population estimates a key socio economic factor infuencing the mental health outcomes including mental health.
#
# *  [Documentation Link](https://www.ers.usda.gov/data-products/county-level-data-sets/documentation)

# %% [markdown]
# **Data Dictionary for Population 2023 data file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Unemployment data
#
# * [Data set Link](https://www.google.com/url?q=https%3A%2F%2Fwww.ers.usda.gov%2Fdata-products%2Fcounty-level-data-sets%2Fcounty-level-data-sets-download-data)
#
# * Owner of the data is from U.S. Census Bureau, Population Estimates Program.
#
# * The data collected from intercensal tables (1990-2010) and vintage population estimates (2020, 2023).
#
# * The date is from 1990 and 2010 year for all the United States county level.
#
# * the data set consists of population estimation of data for each year and those values.
#
# *   This data give insights about the demographic cotests of population estimates a key socio economic factor infuencing the mental health outcomes including mental health.
#
# *  [Documentation Link](https://www.ers.usda.gov/data-products/county-level-data-sets/documentation)

# %% [markdown]
# **Data Dictionary for Unemployment 2023 data file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Data Dictionary 2023

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Data Dictionary 2019

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Importing Necessary Libraries, Data Loading, and Data Cleaning (Handling Missing Values, Duplicates, and Outliers)

# %% [markdown]
# ####**Importing Necessary Libraries**

# %%
# -- mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# -- Importing necessary libraries

# -- Data handling and manipulation
import pandas as pd
import numpy as np

# -- Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# -- Machine Learning libraries
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from imblearn.over_sampling import SMOTE
from sklearn.metrics import roc_curve, auc

# -- Regression models and performance evaluation
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# -- Classification models and performance evaluation
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import make_scorer, recall_score

# -- Decision tree visualization
from sklearn import tree
import graphviz

# %% [markdown]
# ####**Data Loading**

# %%
# -- loading data files
analytics_file_path_23 = "/content/drive/MyDrive/Mlpp_mid_term_data_Gayathri_Emuru/analytic_data2023_0.csv"
analytics_file_path_19 = "/content/drive/MyDrive/Mlpp_mid_term_data_Gayathri_Emuru/analytic_data2019.csv"
poverty_file_path = "https://ers.usda.gov/sites/default/files/_laserfiche/DataFiles/48747/Poverty2023.csv"
pop_est_file_path = "https://ers.usda.gov/sites/default/files/_laserfiche/DataFiles/48747/PopulationEstimates.csv"
educ_affir_file_path = "https://ers.usda.gov/sites/default/files/_laserfiche/DataFiles/48747/Education2023.csv"
unemployemnt_path = "https://ers.usda.gov/sites/default/files/_laserfiche/DataFiles/48747/Unemployment2023.csv"

#reading all data files
analytics_23_df = pd.read_csv(analytics_file_path_23, skiprows=1)
analytics_19_df = pd.read_csv(analytics_file_path_19, skiprows=1)
poverty_23_df = pd.read_csv(poverty_file_path)
pop_est_23_df = pd.read_csv(pop_est_file_path, encoding="utf-8", encoding_errors="replace")
educ_affir_df = pd.read_csv(educ_affir_file_path, encoding="utf-8", encoding_errors="replace")
unemploy_df = pd.read_csv(unemployemnt_path, encoding="utf-8", encoding_errors="replace")

# %% [markdown]
# ####**Data Cleaning (Handling Missing Values, Duplicates)**

# %% [markdown]
# ######**Analytics 2023 data**

# %%
# -- list top 5 rows of 2023 analytics data
analytics_23_df.head()
# Out:
#    statecode  countycode  fipscode state          county  year  county_ranked  \
# 0          0           0         0    US   United States  2023            NaN
# 1          1           0      1000    AL         Alabama  2023            NaN
# 2          1           1      1001    AL  Autauga County  2023            1.0
# 3          1           3      1003    AL  Baldwin County  2023            1.0
# 4          1           5      1005    AL  Barbour County  2023            1.0
#
#    v001_rawvalue  v001_numerator  v001_denominator  ...  v057_rawvalue  \
# 0    7281.935564       4125218.0       917267406.0  ...       0.504707
# 1   10350.071456         88086.0        13668498.0  ...       0.514254
# 2    8027.394727           836.0          156081.0  ...       0.513783
# 3    8118.358206          3377.0          614143.0  ...       0.513477
# 4   12876.760319           539.0           68126.0  ...       0.467033
#
# ...

# %%
# -- print shape of 2023 analytics data
analytics_23_df.shape
# Out:
# (3194, 720)

# %%
# -- reading 2023 analytics data columns into a list
print(analytics_23_df.columns.to_list())
# Out:
# ['statecode', 'countycode', 'fipscode', 'state', 'county', 'year', 'county_ranked', 'v001_rawvalue', 'v001_numerator', 'v001_denominator', 'v001_cilow', 'v001_cihigh', 'v001_flag', 'v001_race_aian', 'v001_race_aian_cilow', 'v001_race_aian_cihigh', 'v001_race_aian_flag', 'v001_race_asian', 'v001_race_asian_cilow', 'v001_race_asian_cihigh', 'v001_race_asian_flag', 'v001_race_black', 'v001_race_black_cilow', 'v001_race_black_cihigh', 'v001_race_black_flag', 'v001_race_hispanic', 'v001_race_hispanic_cilow', 'v001_race_hispanic_cihigh', 'v001_race_hispanic_flag', 'v001_race_white', 'v001_race_white_cilow', 'v001_race_white_cihigh', 'v001_race_white_flag', 'v002_rawvalue', 'v002_numerator', 'v002_denominator', 'v002_cilow', 'v002_cihigh', 'v036_rawvalue', 'v036_numerator', 'v036_denominator', 'v036_cilow', 'v036_cihigh', 'v042_rawvalue', 'v042_numerator', 'v042_denominator', 'v042_cilow', 'v042_cihigh', 'v037_rawvalue', 'v037_numerator', 'v037_denominator', 'v037_cilow', 'v037_cihigh', 'v0
# ...

# %%
#--from list of 720 columns selecting the coulumns that are relevant or needed for the problem statement

# -- v042_rawvalue -- Poor_Mental_Health_Days(average days per month)
# -- v070_rawvalue -- Physical Inactivity raw value (% of adults inactive)
# -- v063_rawvalue -- Median Household Income raw value (dollars)
# -- v052_rawvalue -- % Below 18 Years of Age raw value (percent of population)
# -- v053_rawvalue -- % 65 and Older raw value (percent of population)
# -- v054_rawvalue -- % Non-Hispanic Black raw value (percentage)
# -- v055_rawvalue -- % American Indian or Alaska Native raw value (percentage)
# -- v081_rawvalue -- % Asian raw value (percentage)
# -- v080_rawvalue -- % Native Hawaiian or Other Pacific Islander raw value (percentage)
# -- v056_rawvalue -- % Hispanic raw value (percentage)
# -- v126_rawvalue -- % Non-Hispanic White raw value (percentage)
# -- v009_rawvalue -- % Adult Smoking raw value (percent of adults who smoke)
# -- v011_rawvalue -- Adult Obesity raw value (percent of adults obese)
# -- v133_rawvalue -- Food Environment Index raw value (0-10 scale)
# -- v132_rawvalue -- Access to Exercise Opportunities raw value (percent)
# -- v049_rawvalue -- Excessive Drinking raw value  (percentage)
# -- v136_rawvalue -- Severe Housing Problems raw value (percentage)
# -- v125_rawvalue -- Air Pollution - Particulate Matter raw value (Ug/m^3)
# -- v143_rawvalue -- Insufficient Sleep raw value (percentage)
# -- v060_rawvalue -- Diabetes Prevalence raw value (percentage)
# -- v139_rawvalue -- Food Insecurity raw value (percentage)
# -- v085_rawvalue -- Uninsured raw value
# -- v082_rawvalue -- Children in Single-Parent Households raw value
# -- v161_rawvalue -- Suicides raw value
# -- v062_rawvalue -- Mental Health Providers raw value


# -- list of required columns needed for problem statement
cols=[
    "fipscode",
    "year",
    "v042_rawvalue",
    "v070_rawvalue",
    "v063_rawvalue",
    "v052_rawvalue",
    "v053_rawvalue",
    "v054_rawvalue",
    "v055_rawvalue",
    "v081_rawvalue",
    "v080_rawvalue",
    "v056_rawvalue",
    "v126_rawvalue",
    "v009_rawvalue",
    "v011_rawvalue",
    "v133_rawvalue",
    "v132_rawvalue",
    "v049_rawvalue",
    "v136_rawvalue",
    "v125_rawvalue",
    "v060_rawvalue",
    "v139_rawvalue",
    "v085_rawvalue",
    "v082_rawvalue",
    "v161_rawvalue",
    "v143_rawvalue",
    "v062_rawvalue"
]

# -- update data frame with required list columns and print top 5 rows
analytics_23_df = analytics_23_df[cols]
analytics_23_df.head()
# Out:
#    fipscode  year  v042_rawvalue  v070_rawvalue  v063_rawvalue  v052_rawvalue  \
# 0         0  2023       4.400000          0.220        69717.0       0.221657
# 1      1000  2023       5.073277          0.278        53990.0       0.222674
# 2      1001  2023       4.797351          0.264        66444.0       0.234064
# 3      1003  2023       4.753750          0.232        65658.0       0.212183
# 4      1005  2023       4.954855          0.357        38649.0       0.205496
#
#    v053_rawvalue  v054_rawvalue  v055_rawvalue  v081_rawvalue  ...  \
# 0       0.168271       0.126120       0.013159       0.061316  ...
# 1       0.176357       0.265120       0.007144       0.015504  ...
# 2       0.160487       0.207310       0.004586       0.012031  ...
# 3       0.214698       0.083679       0.008003       0.011225  ...
# 4       0.199768       0.473963       0.007250       0.004607  ...
#
#    v049_rawvalue  v136_rawvalue  v125_rawvalue  v060_rawvalue  v139_rawvalue  \
# ...

# %%
# -- rename the column names to appropriate names in 2023 analytics data
analytics_23_df.rename(columns={
    "v042_rawvalue": "Poor_Mental_Health_Days",
    "v070_rawvalue": "Physical_Inactivity_pct",
    "v063_rawvalue": "Median_Household_Income",
    "v052_rawvalue": "Below_age_18_pct",
    "v053_rawvalue": "age_above_eq_65_pct",
    "v054_rawvalue": "Non-Hispanic_Black_pct",
    "v055_rawvalue": "American_Indian_or_Alaska Native_pct",
    "v081_rawvalue": "Asian_pct",
    "v080_rawvalue": "race_other_pct",
    "v056_rawvalue": "Hispanic_pct",
    "v126_rawvalue": "Non-Hispanic_White_pct",
    "v011_rawvalue": "Adult_Obesity_pct",
    "v133_rawvalue": "Food_Environment_Index",
    "v132_rawvalue": "Access_to_Exercise_Opportunities_pct",
    "v049_rawvalue": "Excessive_Drinking_pct",
    "v136_rawvalue": "Severe_Housing_Problems_pct",
    "v125_rawvalue": "Air_Pollution_Particulate_Matter",
    "v060_rawvalue": "Diabetes_Prevalence_pct",
    "v085_rawvalue": "Uninsured_pct",
    "v082_rawvalue": "Children_in_Single-Parent_Households_pct",
    "v161_rawvalue": "Suicides_rawvalue",
    "v062_rawvalue": "Mental_Health_Providers_ratio",
    "v139_rawvalue": "Food_Insecurity_pct",
    "v009_rawvalue": "Adult_Smoking_pct",
    "v143_rawvalue": "Insufficient_Sleep_pct"
}, inplace = True)

analytics_23_df.head()
# Out:
# <ipython-input-637-b1cd3259ad25>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    fipscode  year  Poor_Mental_Health_Days  Physical_Inactivity_pct  \
# 0         0  2023                 4.400000                    0.220
# 1      1000  2023                 5.073277                    0.278
# 2      1001  2023                 4.797351                    0.264
# 3      1003  2023                 4.753750                    0.232
# 4      1005  2023                 4.954855                    0.357
#
#    Median_Household_Income  Below_age_18_pct  age_above_eq_65_pct  \
# 0                  69717.0          0.221657             0.168271
# 1                  53990.0          0.222674             0.176357
# 2                  66444.0          0.234064             0.160487
# ...

# %%
# -- print list of column names of 2023 analytics data
analytics_23_df.columns
# Out:
# Index(['fipscode', 'year', 'Poor_Mental_Health_Days',
#        'Physical_Inactivity_pct', 'Median_Household_Income',
#        'Below_age_18_pct', 'age_above_eq_65_pct', 'Non-Hispanic_Black_pct',
#        'American_Indian_or_Alaska Native_pct', 'Asian_pct', 'race_other_pct',
#        'Hispanic_pct', 'Non-Hispanic_White_pct', 'Adult_Smoking_pct',
#        'Adult_Obesity_pct', 'Food_Environment_Index',
#        'Access_to_Exercise_Opportunities_pct', 'Excessive_Drinking_pct',
#        'Severe_Housing_Problems_pct', 'Air_Pollution_Particulate_Matter',
#        'Diabetes_Prevalence_pct', 'Food_Insecurity_pct', 'Uninsured_pct',
#        'Children_in_Single-Parent_Households_pct', 'Suicides_rawvalue',
#        'Insufficient_Sleep_pct', 'Mental_Health_Providers_ratio'],
#       dtype='object')

# %% [markdown]
# **Handle NaN values**

# %%
# -- check data has nan values
analytics_23_df.isna().sum()
# Out:
# fipscode                                      0
# year                                          0
# Poor_Mental_Health_Days                       2
# Physical_Inactivity_pct                       2
# Median_Household_Income                       2
# Below_age_18_pct                              0
# age_above_eq_65_pct                           0
# Non-Hispanic_Black_pct                        0
# American_Indian_or_Alaska Native_pct          0
# Asian_pct                                     0
# race_other_pct                                0
# Hispanic_pct                                  0
# Non-Hispanic_White_pct                        0
# Adult_Smoking_pct                             2
# Adult_Obesity_pct                             2
# Food_Environment_Index                       33
# Access_to_Exercise_Opportunities_pct         62
# Excessive_Drinking_pct                        2
# Severe_Housing_Problems_pct                   0
# Air_Pollution_Particulate_Matter             27
# ...

# %% [markdown]
# In [Documentation](https://www.countyhealthrankings.org/sites/default/files/media/document/2023%20CHRR%20Technical%20Document.pdf) at 13th page it mentioned that the if a value is displayed as missing (.) or blank that means data is unavailable for that county or race/ethnicity group. This
# could mean data is unavailable, unreliable, or has been suppressed due to small numbers and resulting privacy
# concerns. Data suppression guidelines are generally established by the data sources.

# %% [markdown]
# Due to the presence of 709 missing values, we are dropping Suicides_rawvalue variable since imputation is not suitable. For the remaining variables with missing values, will replace them using the imputaiton mean/median.

# %%
# -- drop column Suicides_rawvalue
analytics_23_df = analytics_23_df.drop(columns=["Suicides_rawvalue"])

# %% [markdown]
# Non-Hispanic_Black_pct: mean = 0.09, median = 0.02, diff = 0.07
#
# American_Indian_or_Alaska Native_pct: mean = 0.02, median = 0.01, diff = 0.02
#
# Asian_pct: mean = 0.02, median = 0.01, diff = 0.01
#
# race_other_pct: mean = 0.00, median = 0.00, diff = 0.00
#
# Hispanic_pct: mean = 0.10, median = 0.05, diff = 0.05
#
# Uninsured_pct: mean = 0.12, median = 0.11, diff = 0.01
#
# Mental_Health_Providers_ratio: mean = 0.00, median = 0.00, diff = 0.00

# %% [markdown]
# To replace NaN missing values, I tried two imputation methods: mean and median.
#
# Mean imputation uses the average of all observed values. Because Non-Hispanic_Black_pct is right-skewed with outliers, its mean is 0.09, which pulls the imputed values toward extremes.
#
# Median imputation sorts the data and picks the middle value, so it isn't influenced by outliers. For Non-Hispanic_Black_pct, the median is 0.02.
#
# The difference between mean and median is 0.07, showing how mean imputation can inject extreme values. Therefore, we proceed with median imputation.

# %%
# also checkk the mean, and if both are different then outliers are present, so replace the outliers with median

# -- replalcing nan values with the median
num_cols_analytics = analytics_23_df.select_dtypes(include=['float64']).columns
col_median = analytics_23_df[num_cols_analytics].median()
analytics_23_df.loc[:, num_cols_analytics] = analytics_23_df[num_cols_analytics].fillna(col_median)

print(analytics_23_df.isna().sum())
# Out:
# fipscode                                    0
# year                                        0
# Poor_Mental_Health_Days                     0
# Physical_Inactivity_pct                     0
# Median_Household_Income                     0
# Below_age_18_pct                            0
# age_above_eq_65_pct                         0
# Non-Hispanic_Black_pct                      0
# American_Indian_or_Alaska Native_pct        0
# Asian_pct                                   0
# race_other_pct                              0
# Hispanic_pct                                0
# Non-Hispanic_White_pct                      0
# Adult_Smoking_pct                           0
# Adult_Obesity_pct                           0
# Food_Environment_Index                      0
# Access_to_Exercise_Opportunities_pct        0
# Excessive_Drinking_pct                      0
# Severe_Housing_Problems_pct                 0
# Air_Pollution_Particulate_Matter            0
# ...

# %% [markdown]
# **Handle Duplicate Observations**

# %%
# -- check for duplicates
duplicates = analytics_23_df[analytics_23_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, year, Poor_Mental_Health_Days, Physical_Inactivity_pct, Median_Household_Income, Below_age_18_pct, age_above_eq_65_pct, Non-Hispanic_Black_pct, American_Indian_or_Alaska Native_pct, Asian_pct, race_other_pct, Hispanic_pct, Non-Hispanic_White_pct, Adult_Smoking_pct, Adult_Obesity_pct, Food_Environment_Index, Access_to_Exercise_Opportunities_pct, Excessive_Drinking_pct, Severe_Housing_Problems_pct, Air_Pollution_Particulate_Matter, Diabetes_Prevalence_pct, Food_Insecurity_pct, Uninsured_pct, Children_in_Single-Parent_Households_pct, Insufficient_Sleep_pct, Mental_Health_Providers_ratio]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# There is no duplicates in the dataset

# %%
analytics_23_df.describe()
# Out:
#            fipscode    year  Poor_Mental_Health_Days  Physical_Inactivity_pct  \
# count   3194.000000  3194.0              3194.000000              3194.000000
# mean   30351.417032  2023.0                 4.794983                 0.256615
# std    15179.045587     0.0                 0.627917                 0.051841
# min        0.000000  2023.0                 2.779181                 0.102000
# 25%    18171.500000  2023.0                 4.373345                 0.219000
# 50%    29174.000000  2023.0                 4.813037                 0.251000
# 75%    45074.500000  2023.0                 5.220723                 0.291000
# max    56045.000000  2023.0                 6.945581                 0.472000
#
#        Median_Household_Income  Below_age_18_pct  age_above_eq_65_pct  \
# count              3194.000000       3194.000000          3194.000000
# mean              59099.767063          0.219697             0.199929
# ...

# %% [markdown]
# The key observations are county's median household income is about 56.8k at 75% percentage but at max 150k which pulls the overall average. Its reasonable a small number of wealthy people so there is some ouliers
#
# For the demograhic Non-Hispanic_Black_pct extremed nearly 75% of counties have 10% but on maximum it reaches is 85% and also the American_Indian_or_Alaska Native_pct has 0.014 and max is 0.922 and it has more outliers and also other has high values.

# %% [markdown]
# In [Documentation](https://www.google.com/url?q=https%3A%2F%2Fwww.countyhealthrankings.org%2Fsites%2Fdefault%2Ffiles%2Fmedia%2Fdocument%2F2023%2520CHRR%2520Technical%2520Document.pdf) at page 15 the team defines the five OMB race/ethnicity categories, American Indian & Alaska Native, Asian, Black, Hispanic, and White and states that each county's estimate falls into exactly one group. It does not explain why some counties show a strong right skew (e.g., a few counties having very high non-Hispanic Black percentages); that skew reflects real demographic concentrations in certain areas rather than a methodological artifact.

# %% [markdown]
# ######Poverty 2023 data

# %%
# -- list top 5 rows of poverty data
poverty_23_df.head(100)
# Out:
#     FIPS_Code Stabr       Area_Name        Attribute       Value
# 0           0    US   United States      POVALL_2023  40763043.0
# 1           0    US   United States   CI90LBALL_2023  40485829.0
# 2           0    US   United States   CI90UBALL_2023  41040257.0
# 3           0    US   United States   PCTPOVALL_2023        12.5
# 4           0    US   United States  CI90LBALLP_2023        12.4
# ..        ...   ...             ...              ...         ...
# 95       1003    AL  Baldwin County      POV517_2023      5105.0
# 96       1003    AL  Baldwin County   CI90LB517_2023      3889.0
# 97       1003    AL  Baldwin County   CI90UB517_2023      6321.0
# 98       1003    AL  Baldwin County   PCTPOV517_2023        13.0
# 99       1003    AL  Baldwin County  CI90LB517P_2023         9.9
#
# [100 rows x 5 columns]

# %%
# -- rename the columns to appropriate names of poverty data
poverty_23_df.rename(columns={
    "Stabr": "state",
    "FIPS_Code": "fipscode",
    "Value": "Proverty_pct"
},inplace=True)

# -- list top 5 rows
poverty_23_df.head()
# Out:
#    fipscode state      Area_Name        Attribute  Proverty_pct
# 0         0    US  United States      POVALL_2023    40763043.0
# 1         0    US  United States   CI90LBALL_2023    40485829.0
# 2         0    US  United States   CI90UBALL_2023    41040257.0
# 3         0    US  United States   PCTPOVALL_2023          12.5
# 4         0    US  United States  CI90LBALLP_2023          12.4

# %%
# -- filter rows where fipscode is zero and then get unique state values
fips_0 = poverty_23_df[poverty_23_df["fipscode"]==0]['state'].unique()
print(fips_0)
# Out:
# ['US']

# %%
# -- removing rows having fips code 0 because its state value is united states we need state level data set
poverty_23_df = poverty_23_df[poverty_23_df["fipscode"] !=0]
poverty_23_df.count()
# Out:
# fipscode        79934
# state           79934
# Area_Name       79934
# Attribute       79934
# Proverty_pct    79934
# dtype: int64

# %%
# -- check all unique attribute values by selecting random one fipscode
poverty_23_df[poverty_23_df["fipscode"] == 1003]
# Out:
#      fipscode state       Area_Name                        Attribute  \
# 79       1003    AL  Baldwin County  Rural_Urban_Continuum_Code_2013
# 80       1003    AL  Baldwin County        Urban_Influence_Code_2013
# 81       1003    AL  Baldwin County  Rural_Urban_Continuum_Code_2023
# 82       1003    AL  Baldwin County        Urban_Influence_Code_2024
# 83       1003    AL  Baldwin County                      POVALL_2023
# 84       1003    AL  Baldwin County                   CI90LBALL_2023
# 85       1003    AL  Baldwin County                   CI90UBALL_2023
# 86       1003    AL  Baldwin County                   PCTPOVALL_2023
# 87       1003    AL  Baldwin County                  CI90LBALLP_2023
# 88       1003    AL  Baldwin County                  CI90UBALLP_2023
# 89       1003    AL  Baldwin County                      POV017_2023
# 90       1003    AL  Baldwin County                   CI90LB017_2023
# 91       1003    AL  Baldwin County                   CI90UB017_2023
# ...

# %% [markdown]
# From the dataset, I am selecting the variable poverty percentage for the year 2023 (PCTPOVALL_2023). By adding poverty and other socioeconomic factors, we analyze their impact on the target variable mental health illness

# %%
# -- extract and store attribute values having percentage of all people in poverty in 2023
poverty_23_df = poverty_23_df[poverty_23_df["Attribute"] == "PCTPOVALL_2023"]
poverty_23_df.count()
# Out:
# fipscode        3194
# state           3194
# Area_Name       3194
# Attribute       3194
# Proverty_pct    3194
# dtype: int64

# %%
# -- check all unique attribute values by selecting random one fipscode
poverty_23_df[poverty_23_df["fipscode"] == 1003]
# Out:
#     fipscode state       Area_Name       Attribute  Proverty_pct
# 86      1003    AL  Baldwin County  PCTPOVALL_2023          10.0

# %% [markdown]
# **Handle NaN values**

# %%
# -- check data has nan values
poverty_23_df.isna().sum()
# Out:
# fipscode        0
# state           0
# Area_Name       0
# Attribute       0
# Proverty_pct    0
# dtype: int64

# %% [markdown]
# No missing values in dataset

# %% [markdown]
# **Handle Duplicate Observations**

# %%
# -- check for duplicates
duplicates = poverty_23_df[poverty_23_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, state, Area_Name, Attribute, Proverty_pct]
# Index: []

# %% [markdown]
# There is no duplicates in the dataset

# %%
# -- statistics description of  poverty data
poverty_23_df.describe()
# Out:
#            fipscode  Proverty_pct
# count   3194.000000   3194.000000
# mean   30350.524421     14.454915
# std    15179.619983      5.524952
# min     1000.000000      3.300000
# 25%    18171.500000     10.500000
# 50%    29174.000000     13.500000
# 75%    45074.500000     17.300000
# max    56045.000000     49.600000

# %% [markdown]
# The Poverty rates are in 10% to 17% but a minority of counties experience extreme poverty levels.

# %% [markdown]
# ######Population Estimation 2023 data

# %%
# -- list top 5 rows of population data
pop_est_23_df.head()
# Out:
#    FIPStxt State      Area_Name            Attribute        Value
# 0        0    US  United States      CENSUS_2020_POP  331449281.0
# 1        0    US  United States  ESTIMATES_BASE_2020  331464948.0
# 2        0    US  United States    POP_ESTIMATE_2020  331526933.0
# 3        0    US  United States    POP_ESTIMATE_2021  332048977.0
# 4        0    US  United States    POP_ESTIMATE_2022  333271411.0

# %%
# -- Rename column names to appropriate names
pop_est_23_df.rename(columns={
    "State": "state",
    "FIPStxt": "fipscode",
    "Value": "Pop_est_val"
},inplace=True)

pop_est_23_df.head(7)
# Out:
#    fipscode state      Area_Name            Attribute  Pop_est_val
# 0         0    US  United States      CENSUS_2020_POP  331449281.0
# 1         0    US  United States  ESTIMATES_BASE_2020  331464948.0
# 2         0    US  United States    POP_ESTIMATE_2020  331526933.0
# 3         0    US  United States    POP_ESTIMATE_2021  332048977.0
# 4         0    US  United States    POP_ESTIMATE_2022  333271411.0
# 5         0    US  United States    POP_ESTIMATE_2023  334914895.0
# 6         0    US  United States       N_POP_CHG_2020      61985.0

# %% [markdown]
# Above, we can observe there are different Attributes and they contain different corresponding values, but as we want the Population value for each county in 2023, we will use the 'POP_ESTIMATE_2023' Attribute Value

# %%
# -- filter rows having attribute value population estimate of 2023 year
pop_est_23_df = pop_est_23_df[pop_est_23_df["Attribute"] == "POP_ESTIMATE_2023"]
pop_est_23_df.count()
# Out:
# fipscode       3275
# state          3275
# Area_Name      3275
# Attribute      3275
# Pop_est_val    3275
# dtype: int64

# %%
# -- list top 5 rows of population estimation data
pop_est_23_df.head()
# Out:
#      fipscode state       Area_Name          Attribute  Pop_est_val
# 5           0    US   United States  POP_ESTIMATE_2023  334914895.0
# 61       1000    AL         Alabama  POP_ESTIMATE_2023    5108468.0
# 126      1001    AL  Autauga County  POP_ESTIMATE_2023      60342.0
# 191      1003    AL  Baldwin County  POP_ESTIMATE_2023     253507.0
# 256      1005    AL  Barbour County  POP_ESTIMATE_2023      24585.0

# %%
# -- get fipscode values having value 0 and uniqiue state names
fips_0 = pop_est_23_df[pop_est_23_df["fipscode"]==0]['state'].unique()
print(fips_0)
# Out:
# ['US']

# %%
# -- extract rows where fips code is not 0
pop_est_23_df = pop_est_23_df[pop_est_23_df["fipscode"] !=0]

# %% [markdown]
# **Handle NaN values**

# %%
# -- check data has nan values
pop_est_23_df.isna().sum()
# Out:
# fipscode       0
# state          0
# Area_Name      0
# Attribute      0
# Pop_est_val    0
# dtype: int64

# %% [markdown]
# No missing values in dataset

# %% [markdown]
# **Handle Duplicate Observations**

# %%
# -- check for duplicates
duplicates = pop_est_23_df[pop_est_23_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, state, Area_Name, Attribute, Pop_est_val]
# Index: []

# %% [markdown]
# There is no duplicates in the dataset

# %%
pop_est_23_df.describe()
# Out:
#            fipscode   Pop_est_val
# count   3274.000000  3.274000e+03
# mean   31352.645999  2.065489e+05
# std    16305.778172  1.264895e+06
# min     1000.000000  4.300000e+01
# 25%    19023.500000  1.117750e+04
# 50%    30020.000000  2.687700e+04
# 75%    46100.500000  7.297425e+04
# max    72153.000000  3.896519e+07

# %% [markdown]
# County population are heavily skewed with most counties housing fewer than 75,000 people but a few outliers.

# %% [markdown]
# ######Education Affirmations 2019-2023 data

# %%
# -- lsit top 5 rows of education affirmations data
educ_affir_df.head()
# Out:
#    FIPS Code State      Area name  \
# 0          0    US  United States
# 1          0    US  United States
# 2          0    US  United States
# 3          0    US  United States
# 4          0    US  United States
#
#                                            Attribute       Value
# 0              Less than a high school diploma, 1970  52373312.0
# 1                     High school diploma only, 1970  34158051.0
# 2                     Some college (1-3 years), 1970  11650730.0
# 3              Four years of college or higher, 1970  11717266.0
# 4  Percent of adults with less than a high school...        47.7

# %%
# -- print column names of education affirmation data
educ_affir_df.columns
# Out:
# Index(['FIPS Code', 'State', 'Area name', 'Attribute', 'Value'], dtype='object')

# %%
#-- Rename columns to appropriate names
educ_affir_df.rename(columns={
    "State": "state",
    "FIPS Code": "fipscode",
    "Value": "Educ_affir_pct"
}, inplace=True)

educ_affir_df.head(7)
# Out:
#    fipscode state      Area name  \
# 0         0    US  United States
# 1         0    US  United States
# 2         0    US  United States
# 3         0    US  United States
# 4         0    US  United States
# 5         0    US  United States
# 6         0    US  United States
#
#                                            Attribute  Educ_affir_pct
# 0              Less than a high school diploma, 1970      52373312.0
# 1                     High school diploma only, 1970      34158051.0
# 2                     Some college (1-3 years), 1970      11650730.0
# 3              Four years of college or higher, 1970      11717266.0
# 4  Percent of adults with less than a high school...            47.7
# 5  Percent of adults with a high school diploma o...            31.1
# 6  Percent of adults completing some college (1-3...            10.6

# %%
# -- extract rows having attribute column value Percent of adults who are not high school graduates, 2019-23
educ_affir_df = educ_affir_df[educ_affir_df["Attribute"] == "Percent of adults who are not high school graduates, 2019-23"]
educ_affir_df.count()
# Out:
# fipscode          3275
# state             3275
# Area name         3275
# Attribute         3275
# Educ_affir_pct    3275
# dtype: int64

# %%
# -- get fipscode values having value 0 and uniqiue state names
fips_0 = educ_affir_df[educ_affir_df["fipscode"]==0]['state'].unique()
print(fips_0)
# Out:
# ['US']

# %%
# -- select  rows having fipscode not equal to zero
educ_affir_df = educ_affir_df[educ_affir_df["fipscode"] !=0]

# %% [markdown]
# **Handle NaN values**

# %%
# -- check data has nan values
educ_affir_df.isna().sum()
# Out:
# fipscode          0
# state             0
# Area name         0
# Attribute         0
# Educ_affir_pct    0
# dtype: int64

# %% [markdown]
# No missing values in dataset

# %% [markdown]
# **Handle Duplicate Observations**

# %%
duplicates = educ_affir_df[educ_affir_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, state, Area name, Attribute, Educ_affir_pct]
# Index: []

# %% [markdown]
# There is no duplicates in the dataset

# %%
educ_affir_df.describe()
# Out:
#            fipscode  Educ_affir_pct
# count   3274.000000     3274.000000
# mean   31352.645999       11.469439
# std    16305.778172        5.693344
# min     1000.000000        0.000000
# 25%    19023.500000        7.296311
# 50%    30020.000000       10.219261
# 75%    46100.500000       14.643641
# max    72153.000000       53.191489

# %% [markdown]
# The distribution of Education affirmations is moderately right skewed and most counties cluster around 7 to 15% but a few attaintment counties drive the mean above the median.

# %% [markdown]
# ######unemployment percentage data for 2019 and 2023 year

# %%
unemploy_df.head()
# Out:
#    FIPS_Code State      Area_Name                  Attribute        Value
# 0          0    US  United States  Civilian_labor_force_2000  142601576.0
# 1          0    US  United States              Employed_2000  136904853.0
# 2          0    US  United States            Unemployed_2000    5696723.0
# 3          0    US  United States     Unemployment_rate_2000          4.0
# 4          0    US  United States  Civilian_labor_force_2001  143786537.0

# %%
# -- filter and store rows having Attribute column values as unemployment rate of all years
unemploy_df = unemploy_df[unemploy_df["Attribute"].str.contains("Unemployment_rate_2023")]

# %%
unemploy_df.columns
# Out:
# Index(['FIPS_Code', 'State', 'Area_Name', 'Attribute', 'Value'], dtype='object')

# %%
unemploy_df.head()
# Out:
#      FIPS_Code State           Area_Name               Attribute  Value
# 95           0    US       United States  Unemployment_rate_2023    3.6
# 192       1000    AL             Alabama  Unemployment_rate_2023    2.5
# 293       1001    AL  Autauga County, AL  Unemployment_rate_2023    2.2
# 394       1003    AL  Baldwin County, AL  Unemployment_rate_2023    2.3
# 495       1005    AL  Barbour County, AL  Unemployment_rate_2023    4.4

# %%
# -- rename the column names to appropriate names
unemploy_df.rename(columns={
    "State": "state",
    "FIPS_Code": "fipscode",
    "Value":"unemployement_pct",
    "year":"unemployement_year"
}, inplace=True)
# Out:
# <ipython-input-676-aff01442e69c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# -- get fipscode values having value 0 and uniqiue state names
fips_0 = unemploy_df[unemploy_df["fipscode"]==0]['state'].unique()
print(fips_0)

# -- select  rows ahving fipscode not equal to zero
unemploy_df = unemploy_df[unemploy_df["fipscode"] !=0]
# Out:
# ['US']

# %% [markdown]
# **Handle NaN values**

# %%
# -- check data has nan values
unemploy_df.isna().sum()
# Out:
# fipscode             0
# state                0
# Area_Name            0
# Attribute            0
# unemployement_pct    0
# dtype: int64

# %% [markdown]
# No missing values in dataset

# %% [markdown]
# **Handle Duplicate Observations**

# %%
# -- check for duplicates
duplicates = unemploy_df[unemploy_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, state, Area_Name, Attribute, unemployement_pct]
# Index: []

# %% [markdown]
# There is no duplicates in the dataset

# %%
unemploy_df.describe()
# Out:
#            fipscode  unemployement_pct
# count   3272.000000        3272.000000
# mean   31364.080685           3.670507
# std    16304.106856           1.358313
# min     1000.000000           0.300000
# 25%    19026.500000           2.800000
# 50%    30022.000000           3.400000
# 75%    46101.250000           4.200000
# max    72153.000000          17.300000

# %% [markdown]
# County unemployment rates are generally low and tightly grouped but a small number of counties with very high rates create a long tail lifting the mean above the median.

# %% [markdown]
# ######Analytics 2019 data

# %%
# -- list top 5 rows of 2019 analytics data
analytics_19_df.head()
# Out:
#    statecode  countycode  fipscode state          county  year  county_ranked  \
# 0          0           0         0    US   United States  2019            NaN
# 1          1           0      1000    AL         Alabama  2019            NaN
# 2          1           1      1001    AL  Autauga County  2019            1.0
# 3          1           3      1003    AL  Baldwin County  2019            1.0
# 4          1           5      1005    AL  Barbour County  2019            1.0
#
#    v001_rawvalue  v001_numerator  v001_denominator  ...  v013_rawvalue  \
# 0    6900.630354       3745538.0       908266078.0  ...            NaN
# 1    9917.232898         80440.0        13636816.0  ...            NaN
# 2    8824.057123           815.0          156132.0  ...            NaN
# 3    7224.632160          2827.0          576496.0  ...            NaN
# 4    9586.165037           451.0           72222.0  ...            NaN
#
# ...

# %%
# -- print shape of 2023 analytics data
analytics_19_df.shape
# Out:
# (3194, 534)

# %%
# -- reading 2023 analytics data columns into a list
print(analytics_19_df.columns.to_list())
# Out:
# ['statecode', 'countycode', 'fipscode', 'state', 'county', 'year', 'county_ranked', 'v001_rawvalue', 'v001_numerator', 'v001_denominator', 'v001_cilow', 'v001_cihigh', 'v001_race_black', 'v001_race_hispanic', 'v001_race_white', 'v002_rawvalue', 'v002_numerator', 'v002_denominator', 'v002_cilow', 'v002_cihigh', 'v036_rawvalue', 'v036_numerator', 'v036_denominator', 'v036_cilow', 'v036_cihigh', 'v042_rawvalue', 'v042_numerator', 'v042_denominator', 'v042_cilow', 'v042_cihigh', 'v037_rawvalue', 'v037_numerator', 'v037_denominator', 'v037_cilow', 'v037_cihigh', 'v037_race_black', 'v037_race_hispanic', 'v037_race_white', 'v009_rawvalue', 'v009_numerator', 'v009_denominator', 'v009_cilow', 'v009_cihigh', 'v011_rawvalue', 'v011_numerator', 'v011_denominator', 'v011_cilow', 'v011_cihigh', 'v133_rawvalue', 'v133_numerator', 'v133_denominator', 'v133_cilow', 'v133_cihigh', 'v070_rawvalue', 'v070_numerator', 'v070_denominator', 'v070_cilow', 'v070_cihigh', 'v132_rawvalue', 'v132_numerator', 'v1
# ...

# %%
#--from list of 720 columns selecting the coulumns that are relevant or needed for the problem statement

# -- v042_rawvalue -- Poor_Mental_Health_Days(average days per month)
# -- v070_rawvalue -- Physical Inactivity raw value (% of adults inactive)
# -- v009_rawvalue -- % Adult Smoking raw value (percent of adults who smoke)
# -- v011_rawvalue -- Adult Obesity raw value (percent of adults obese)
# -- v132_rawvalue -- Access to Exercise Opportunities raw value (percent)
# -- v049_rawvalue -- Excessive Drinking raw value  (percentage)
# -- v143_rawvalue -- Insufficient Sleep raw value (percentage)
# -- v139_rawvalue -- Food Insecurity raw value (percentage)
# -- state

# -- list of required columns needed for problem statement
cols=[
    "fipscode",
    "year",
    "v042_rawvalue",
    "v070_rawvalue",
    "v009_rawvalue",
    "v011_rawvalue",
    "v132_rawvalue",
    "v049_rawvalue",
    "v143_rawvalue",
    "v139_rawvalue",
    "state"

]
# -- update data frame with required list columns and print top 5 rows
analytics_19_df = analytics_19_df[cols]
analytics_19_df.head()
# Out:
#    fipscode  year  v042_rawvalue  v070_rawvalue  v009_rawvalue  v011_rawvalue  \
# 0         0  2019            NaN          0.222            NaN          0.285
# 1      1000  2019       4.577367          0.282       0.215382          0.351
# 2      1001  2019       4.306739          0.311       0.191247          0.375
# 3      1003  2019       4.249649          0.238       0.167955          0.310
# 4      1005  2019       4.634994          0.282       0.215409          0.443
#
#    v132_rawvalue  v049_rawvalue  v143_rawvalue  v139_rawvalue state
# 0       0.838945            NaN            NaN          0.129    US
# 1       0.616496       0.141781       0.377210          0.165    AL
# 2       0.686775       0.168780       0.359054          0.134    AL
# 3       0.719710       0.167150       0.333059          0.123    AL
# 4       0.536257       0.126987       0.385632          0.232    AL

# %%
# -- rename the column names to appropriate names in 2023 analytics data
analytics_19_df.rename(columns={
    "v042_rawvalue": "Poor_Mental_Health_Days_19",
    "v070_rawvalue": "Physical_Inactivity_pct_19",
    "v011_rawvalue": "Adult_Obesity_pct_19",
    "v132_rawvalue": "Access_to_Exercise_Opportunities_pct_19",
    "v049_rawvalue": "Excessive_Drinking_pct_19",
    "v139_rawvalue": "Food_Insecurity_pct_19",
    "v009_rawvalue": "Adult_Smoking_pct_19",
    "v143_rawvalue": "Insufficient_Sleep_pct_19"
}, inplace = True)

analytics_19_df.head()
# Out:
# <ipython-input-685-d361212f62a2>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    fipscode  year  Poor_Mental_Health_Days_19  Physical_Inactivity_pct_19  \
# 0         0  2019                         NaN                       0.222
# 1      1000  2019                    4.577367                       0.282
# 2      1001  2019                    4.306739                       0.311
# 3      1003  2019                    4.249649                       0.238
# 4      1005  2019                    4.634994                       0.282
#
#    Adult_Smoking_pct_19  Adult_Obesity_pct_19  \
# 0                   NaN                 0.285
# 1              0.215382                 0.351
# 2              0.191247                 0.375
# 3              0.167955                 0.310
# ...

# %%
# -- get fipscode values having value 0 and uniqiue state names
fips_0 = analytics_19_df[analytics_19_df["fipscode"]==0]['state'].unique()
print(fips_0)

# -- select  rows ahving fipscode not equal to zero
analytics_19_df = analytics_19_df[analytics_19_df["fipscode"] !=0]
# Out:
# ['US']

# %% [markdown]
# **Handlle Nan values**

# %%
# -- check data has nan values
analytics_19_df.isna().sum()
# Out:
# fipscode                                   0
# year                                       0
# Poor_Mental_Health_Days_19                 0
# Physical_Inactivity_pct_19                 0
# Adult_Smoking_pct_19                       0
# Adult_Obesity_pct_19                       0
# Access_to_Exercise_Opportunities_pct_19    6
# Excessive_Drinking_pct_19                  0
# Insufficient_Sleep_pct_19                  0
# Food_Insecurity_pct_19                     0
# state                                      0
# dtype: int64

# %% [markdown]
# Poor_Mental_Health_Days_19: mean = 3.93, median = 3.93, diff = 0.00
#
# Physical_Inactivity_pct_19: mean = 0.26, median = 0.26, diff = 0.00
#
# Adult_Smoking_pct_19: mean = 0.18, median = 0.17, diff = 0.01
#
# Adult_Obesity_pct_19: mean = 0.32, median = 0.32, diff = 0.00
#
# Access_to_Exercise_Opportunities_pct_19: mean = 0.63, median = 0.67, diff = 0.04
# Excessive_Drinking_pct_19: mean = 0.17, median = 0.17, diff = 0.00
#
# Insufficient_Sleep_pct_19: mean = 0.33, median = 0.33, diff = 0.00
#
# Food_Insecurity_pct_19: mean = 0.14, median = 0.13, diff = 0.01

# %% [markdown]
# I tried computing mean and median to handle the missing values , Only the variable Access_to_Exercise_Opportunities_pct_19 has missing values (6 total). Its mean is 0.63 and its median is 0.67 a difference of just 0.04, indicating mild right skew. All other features show no difference between mean and median. Because of this skew, median imputation is the most appropriate method for filling in the missing values.

# %%
# -- replalcing nan values with the median
num_cols_analytics_19 = analytics_19_df.select_dtypes(include=['float64']).columns
col_median = analytics_19_df[num_cols_analytics_19].median()
analytics_19_df.loc[:, num_cols_analytics_19] = analytics_19_df[num_cols_analytics_19].fillna(col_median)

print(analytics_19_df.isna().sum())
# Out:
# fipscode                                   0
# year                                       0
# Poor_Mental_Health_Days_19                 0
# Physical_Inactivity_pct_19                 0
# Adult_Smoking_pct_19                       0
# Adult_Obesity_pct_19                       0
# Access_to_Exercise_Opportunities_pct_19    0
# Excessive_Drinking_pct_19                  0
# Insufficient_Sleep_pct_19                  0
# Food_Insecurity_pct_19                     0
# state                                      0
# dtype: int64

# %% [markdown]
# **Handle Duplicate Values**

# %%
# -- check for duplicates
duplicates = analytics_19_df[analytics_19_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, year, Poor_Mental_Health_Days_19, Physical_Inactivity_pct_19, Adult_Smoking_pct_19, Adult_Obesity_pct_19, Access_to_Exercise_Opportunities_pct_19, Excessive_Drinking_pct_19, Insufficient_Sleep_pct_19, Food_Insecurity_pct_19, state]
# Index: []

# %%
analytics_19_df.describe()
# Out:
#            fipscode    year  Poor_Mental_Health_Days_19  \
# count   3193.000000  3193.0                 3193.000000
# mean   30360.922643  2019.0                    3.931839
# std    15171.912105     0.0                    0.612364
# min     1000.000000  2019.0                    2.439654
# 25%    18173.000000  2019.0                    3.492944
# 50%    29175.000000  2019.0                    3.932477
# 75%    45075.000000  2019.0                    4.348086
# max    56045.000000  2019.0                    5.964156
#
#        Physical_Inactivity_pct_19  Adult_Smoking_pct_19  Adult_Obesity_pct_19  \
# count                 3193.000000           3193.000000           3193.000000
# mean                     0.256439              0.178669              0.320284
# std                      0.051743              0.036573              0.045884
# min                      0.084000              0.067354              0.136000
# ...

# %% [markdown]
# Most counties center around the medians for each health indicator, but in every case a small minority of counties sit at extreme high values, driving right-skewed distributions. This consistent skew across socio-behavioral factors further supports our use of median based imputation.

# %% [markdown]
# ### Merge 2023 Datasets

# %%
# -- create combined_23_data_df by merging all data sets of poverty, education affirmations, populations affirmation and alaytics data 2023
combined_23_data_df = pd.merge(analytics_23_df, educ_affir_df, on="fipscode", suffixes=('_analytics', '_educ'))
combined_23_data_df = pd.merge(combined_23_data_df, pop_est_23_df, on="fipscode", suffixes=('_pop', '_poverty'))
combined_23_data_df = pd.merge(combined_23_data_df, poverty_23_df, on="fipscode", suffixes=('_poverty', '_unemploy'))
combined_23_data_df = pd.merge(combined_23_data_df, unemploy_df, on="fipscode", suffixes=('_unemploy', '_final'))

combined_23_data_df.head()
# Out:
#    fipscode  year  Poor_Mental_Health_Days  Physical_Inactivity_pct  \
# 0      1000  2023                 5.073277                    0.278
# 1      1001  2023                 4.797351                    0.264
# 2      1003  2023                 4.753750                    0.232
# 3      1005  2023                 4.954855                    0.357
# 4      1007  2023                 5.364779                    0.316
#
#    Median_Household_Income  Below_age_18_pct  age_above_eq_65_pct  \
# 0                  53990.0          0.222674             0.176357
# 1                  66444.0          0.234064             0.160487
# 2                  65658.0          0.212183             0.214698
# 3                  38649.0          0.205496             0.199768
# 4                  48454.0          0.201183             0.167371
#
#    Non-Hispanic_Black_pct  American_Indian_or_Alaska Native_pct  Asian_pct  \
# 0                0.265120                              0.007144   0.015504
# ...

# %%
# -- print list of combined_23_data_df column names
combined_23_data_df.columns
# Out:
# Index(['fipscode', 'year', 'Poor_Mental_Health_Days',
#        'Physical_Inactivity_pct', 'Median_Household_Income',
#        'Below_age_18_pct', 'age_above_eq_65_pct', 'Non-Hispanic_Black_pct',
#        'American_Indian_or_Alaska Native_pct', 'Asian_pct', 'race_other_pct',
#        'Hispanic_pct', 'Non-Hispanic_White_pct', 'Adult_Smoking_pct',
#        'Adult_Obesity_pct', 'Food_Environment_Index',
#        'Access_to_Exercise_Opportunities_pct', 'Excessive_Drinking_pct',
#        'Severe_Housing_Problems_pct', 'Air_Pollution_Particulate_Matter',
#        'Diabetes_Prevalence_pct', 'Food_Insecurity_pct', 'Uninsured_pct',
#        'Children_in_Single-Parent_Households_pct', 'Insufficient_Sleep_pct',
#        'Mental_Health_Providers_ratio', 'state_pop', 'Area name',
#        'Attribute_pop', 'Educ_affir_pct', 'state_poverty', 'Area_Name_poverty',
#        'Attribute_poverty', 'Pop_est_val', 'state_unemploy',
#        'Area_Name_unemploy', 'Attribute_unemploy', 'Proverty_pct',
# ...

# %% [markdown]
# **Handle Duplicate Column Names**

# %%
# -- drop unnecasaary and duplicate columns in combined_23_data_df data
cols_to_drop = ['state_pop', 'Area name', 'Attribute_pop', 'state_poverty', 'Area_Name_poverty', 'Attribute_poverty', 'state_unemploy', 'Area_Name_unemploy', 'Attribute_unemploy', 'Area_Name', 'Attribute_final']
combined_23_data_df.drop(columns=cols_to_drop, inplace=True)

# %%
# -- rename the column names to appropriate names
unemploy_df.rename(columns={"state_final": "state"}, inplace=True)

# %%
# -- print list of combined_23_data_df column names
combined_23_data_df.columns
# Out:
# Index(['fipscode', 'year', 'Poor_Mental_Health_Days',
#        'Physical_Inactivity_pct', 'Median_Household_Income',
#        'Below_age_18_pct', 'age_above_eq_65_pct', 'Non-Hispanic_Black_pct',
#        'American_Indian_or_Alaska Native_pct', 'Asian_pct', 'race_other_pct',
#        'Hispanic_pct', 'Non-Hispanic_White_pct', 'Adult_Smoking_pct',
#        'Adult_Obesity_pct', 'Food_Environment_Index',
#        'Access_to_Exercise_Opportunities_pct', 'Excessive_Drinking_pct',
#        'Severe_Housing_Problems_pct', 'Air_Pollution_Particulate_Matter',
#        'Diabetes_Prevalence_pct', 'Food_Insecurity_pct', 'Uninsured_pct',
#        'Children_in_Single-Parent_Households_pct', 'Insufficient_Sleep_pct',
#        'Mental_Health_Providers_ratio', 'Educ_affir_pct', 'Pop_est_val',
#        'Proverty_pct', 'state_final', 'unemployement_pct'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering & Preprocessing

# %% [markdown]
# The Food Environment Index ranges from 0 to 10, with higher values meaning better access. By inverting it, a higher value now clearly shows more difficulty in getting nutritious food.
#
# The youth-to-elderly ratio highlights population challenges. More young people can mean stress on education and childcare, while more elderly may increase healthcare needs.

# %%
# -- Inverts the Food Environment Index so higher values indicate worse food access
combined_23_data_df['Food_Access_Difficulty'] = 1 - (combined_23_data_df['Food_Environment_Index'] / 10)

# -- Calculates the ratio of young population to elderly population to highlight demographic challenges
combined_23_data_df['Demographic_Vulnerability_Ratio'] = combined_23_data_df['Below_age_18_pct'] / combined_23_data_df['age_above_eq_65_pct']

# %% [markdown]
# **Handle NaN Values**

# %%
# -- check data has nan values
combined_23_data_df.isna().sum()
# Out:
# fipscode                                    0
# year                                        0
# Poor_Mental_Health_Days                     0
# Physical_Inactivity_pct                     0
# Median_Household_Income                     0
# Below_age_18_pct                            0
# age_above_eq_65_pct                         0
# Non-Hispanic_Black_pct                      0
# American_Indian_or_Alaska Native_pct        0
# Asian_pct                                   0
# race_other_pct                              0
# Hispanic_pct                                0
# Non-Hispanic_White_pct                      0
# Adult_Smoking_pct                           0
# Adult_Obesity_pct                           0
# Food_Environment_Index                      0
# Access_to_Exercise_Opportunities_pct        0
# Excessive_Drinking_pct                      0
# Severe_Housing_Problems_pct                 0
# Air_Pollution_Particulate_Matter            0
# ...

# %% [markdown]
# **Handle Duplicate Observations**

# %%
duplicates = combined_23_data_df[combined_23_data_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, year, Poor_Mental_Health_Days, Physical_Inactivity_pct, Median_Household_Income, Below_age_18_pct, age_above_eq_65_pct, Non-Hispanic_Black_pct, American_Indian_or_Alaska Native_pct, Asian_pct, race_other_pct, Hispanic_pct, Non-Hispanic_White_pct, Adult_Smoking_pct, Adult_Obesity_pct, Food_Environment_Index, Access_to_Exercise_Opportunities_pct, Excessive_Drinking_pct, Severe_Housing_Problems_pct, Air_Pollution_Particulate_Matter, Diabetes_Prevalence_pct, Food_Insecurity_pct, Uninsured_pct, Children_in_Single-Parent_Households_pct, Insufficient_Sleep_pct, Mental_Health_Providers_ratio, Educ_affir_pct, Pop_est_val, Proverty_pct, state_final, unemployement_pct, Food_Access_Difficulty, Demographic_Vulnerability_Ratio]
# Index: []
#
# [0 rows x 33 columns]

# %%
# -- rename variable name froms state final to state
combined_23_data_df.rename(columns={'state_final': 'state'}, inplace=True)

# %%
# -- info of data_23
combined_23_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 33 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   fipscode                                  3183 non-null   int64
#  1   year                                      3183 non-null   int64
#  2   Poor_Mental_Health_Days                   3183 non-null   float64
#  3   Physical_Inactivity_pct                   3183 non-null   float64
#  4   Median_Household_Income                   3183 non-null   float64
#  5   Below_age_18_pct                          3183 non-null   float64
#  6   age_above_eq_65_pct                       3183 non-null   float64
#  7   Non-Hispanic_Black_pct                    3183 non-null   float64
#  8   American_Indian_or_Alaska Native_pct      3183 non-null   float64
#  9   Asian_pct                                 3183 non-null   float64
# ...

# %% [markdown]
# All data types of variables are correct hence no need of changing varriable data type

# %% [markdown]
# ### **III. Summary Statistics and Visualizations**

# %% [markdown]
# Summary statistics and visualization help
#  to spot relationships (like which features move together), detect outliers or errors, and judge whether a model's predictions make sense. They also let us share results more clearly—people grasp a picture much faster than a table of numbers. In short, good visuals turn raw data into insights we can both understand and explain.
#
# Moreover, visualizations help us dive deeper into the data so we can pick the best model. For example, if a linear model's assumptions are satisfied, we know its' appropriate to use a linear approach.

# %%
# -- group the data by state and the mean of poor mental health days and drop nan values
state_combined_23_data_df = combined_23_data_df.groupby("state")["Poor_Mental_Health_Days"].mean()
state_combined_19_data_df = analytics_19_df.groupby("state")["Poor_Mental_Health_Days_19"].mean()

# -- drop nan values
state_combined_23_data_df.dropna(inplace=True)
state_combined_19_data_df.dropna(inplace=True)

# -- reset the index
state_combined_23_data_df = state_combined_23_data_df.reset_index()
state_combined_19_data_df = state_combined_19_data_df.reset_index()

# --  Define function to create a choropleth map with rotated color bar labels and units
def create_choropleth(df, value_column, year):
    labs = {value_column: f"Average Mentally Unhealthy Days ({year})"}
    fig = px.choropleth(
        df,
        locations="state",
        color=value_column,
        locationmode="USA-states",
        scope="usa",
        color_continuous_scale="OrRd",
        title=f"Average Poor Mental Health Days by State in {year} U.S",
        labels=labs
    )
    fig.show()

# -- Create maps for 2023 and 2019
create_choropleth(state_combined_19_data_df, "Poor_Mental_Health_Days_19", "2019")
create_choropleth(state_combined_23_data_df, "Poor_Mental_Health_Days", "2023")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The Choropleth map shows the number of average poor mental health days across the states in the U.S for year 2019 and 2023. The darker the red the higher the number of poor mental days reported in that state.
#
# The 2019 map shows each state average number of poor mental health days per month. Darkest reds mark Kentucky (4.5 days), West Virginia (5.1 days), and Louisiana (4.3 days) all states with higher poverty, unemployment, and opioid-related distress. Lighter shades appear in Utah (3.6 days), North Dakota (2.8 days), South Dakota (3.0 days), and Nebraska (3.1 days), where stronger rural health networks and lower economic stress likely contribute to fewer poor mental health days.
#
#
# By 2023, state averages range from about 3.0 to 6.9 days. Kentucky (5.9 days) and Louisiana (5.8 days) remain darkest, reflecting persistent socio-economic challenges like declining coal jobs in Appalachia and ongoing public-health crises in the Gulf South. North Dakota (4.8 days), South Dakota (3.5 days), and Nebraska (3.7 days) stay among the lightest, thanks to relatively stable farm economies and expanding tele-mental health services. Nationally, the average rose from roughly 3-5 days in 2019 to 4-5.5 days in 2023, highlighting a worsening mental health burden.
#
# these geographic differences helps in understanding which state has has high average mental health days and low mental health days.

# %%
# -- plotting the histogram of average poor mental health days for each county in year 2023
sns.histplot(analytics_19_df["Poor_Mental_Health_Days_19"], bins=10, label="2019 PMH")
sns.histplot(combined_23_data_df["Poor_Mental_Health_Days"], bins=10, label="2023 PMH")
plt.title("Distribution of county-level Poor Mental Health Days(2019 vs 2023)")
plt.xlabel("Average Poor Mental Health Days per Month")
plt.ylabel("Number of Counties")
plt.legend()
plt.show()

# %% [markdown]
# The histogram compares the distribution of average poor mental health days per month across U.S. counties in 2019 (blue) and 2023 (orange), using the same 10 bins over a 2.5-7.0 day range.
#
# In 2019, most counties peak between 3.0 and 5.0 days, whereas in 2023 the peak shifts to about 3.8-5.8 days, showing a clear upward trend.
#
# Both distributions are right-skewed, but 2023 has a longer tail beyond 6.0 days, indicating more counties experiencing very high mental distress.
#
# Overall, poor mental health days increased nationwide from 2019 to 2023

# %%
# -- Plot the box plot for poor mental health days
plt.figure(figsize=(6,5))
sns.boxplot(combined_23_data_df["Poor_Mental_Health_Days"])
plt.title("Box Plot of Poor Mental Health Days in U.S Counties 2023")
plt.ylabel("Average Poor Mental Health Days(2023)")
plt.show()

# %% [markdown]
# This box plot explains the distribution of average poor mental health days reported acroos the U.S counties in the year 2023.
# Most Counties fall in the range of 3 to 6.5 days with a median around 4.8 days,. There is some outliers above the whiskers 6.5 days and below the whiskers 3 days indicating the counties mental health outcomes differ noticeably from the majority. This box helps in quickly understanding the meedian, inter quartilr range spread of 50% data and exyteme min and max values.
#
# The poor emntal health is common issue across U.S counties with most individuals on average of 4 to 5 days of poor mental health ina month. However the resence of outliers above 6,5 days shoes that some counties is experiencing worse emntal health conditions sue to socio-economic or regions related. To understand better lets plot by state level

# %%
# -- plotting bar plot for poor mental health days by grouping state and poor mental health days
state_summary = (combined_23_data_df.groupby("state")["Poor_Mental_Health_Days"].mean().sort_values())

plt.figure(figsize=(15,15))
sns.barplot(x=state_summary.values, y=state_summary.index)
plt.title("Average Poor Mental Health Days by U.S State in 2023")
plt.xlabel("Average Poor Mental Health Days")
plt.ylabel("U.S States")
plt.show()

# %% [markdown]
# This horizontal bar plot shows each U.S. state's mean number of poor mental health days per month in 2023. States are sorted from lowest (South Dakota at approximately 3.8 days) to highest (West Virginia at approximately 5.9 days). Most states fall between 4.0 and 5.5 days, but a few like West Virginia and Kentucky exceed 6 days, highlighting particularly severe regional burdens. On the low end, states such as South Dakota and Nebraska average around 3.8-4.0 days, suggesting comparatively better mental health outcomes.
#
# These gaps reveal where socio-economic stressors (like unemployment and provider shortages) are most acute, guiding where to expand mental health services.

# %%
# -- plot the scatter plot unemployment vs poor mental health days in year 2023

plt.figure(figsize=(6,6))
sns.scatterplot(data=combined_23_data_df,x="unemployement_pct", y="Poor_Mental_Health_Days", alpha=0.4, edgecolor=None)
plt.title("Relationship between Unemployment Rate and Poor Mental Health Days in year (2023)")
plt.ylabel("Average Poor Mental Health Days(2023)")
plt.xlabel("Unemployment Rate(%) in 2023")
plt.show()

# %% [markdown]
# According to the analytics documentation the Poor mental health days ranges from 3 to 7.0 because counties are standardized based on health factors, keeping values stable. Social conditions and healthcare access also play a role in shaping this distribution.Poor mental health days range from 3 to 7.0 because counties are standardized based on health factors, keeping values stable. Social conditions and healthcare access also play a role in shaping this distribution.
#
# According to the unemployment documetation, unemployment rate falls between 1% to 6%, explaning the percentage of people actively seeking work. This range is considered normal in a stable economy, where some job turnover is expected.
#
# The U-3 unemployment rate is the most commonly reported measure, representing individuals actively looking for jobs. A lower rate (closer to 1%) suggests strong job availability, while a higher rate (closer to 6%) may indicate economic slowdowns or job losses.

# %% [markdown]
# The scatter explains the relationships between
# the x axis unemployment rates in percentages and the poor mental health days in year 2023 across counties in U.S. Each blue dot is a data point in table. The unemployment rate on x-axis and the average mental unhealthy days on y.axis, most counties cluster between 3.5 to 6.5 poor mental health days and 2% to 7& unemployment rates.
#
# There is a positive trend that as unemployment rates increases, counties tend to report more poor mental health days. However the spread is wide and many counties with similar unemployment rates shoe varied mental health responses indicating that other factors such as income, education or other dactors influences mental health.
#
#
# This plot helps to understand whether unemployment economic stress is linked woth mental health challenges ata the county level. The trend is not linear but it explains that the higher the unemployment the higher the mental health concerns.

# %%
# -- group data by state and calculates the mean unemployment rate and reset the index and srop nan values
state_combined_23_data_df = combined_23_data_df.groupby("state")["unemployement_pct"].mean()
state_combined_23_data_df.dropna(inplace=True)
state_combined_23_data_df = state_combined_23_data_df.reset_index()

# -- create a choropleth using plotly for unemploment year of 2023 year
labs = {"unemployement_pct" : "Average <br>Unemployment<br>Rate"}
fig = px.choropleth(
    state_combined_23_data_df,
    locations="state",
    color="unemployement_pct",
    locationmode="USA-states",
    scope="usa",
    color_continuous_scale="Reds",
    title="Average Unemployment rate by state in year 2023 U.S",
    labels=labs)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The Choropleth map shows the number of unemployment rates across the states in the united states.
#
#  The darker the red the higher the unemployment in that state. The states with higher unemployment is Louisiana, Nevada, Indiana, and Pennsylvania. The tates with lower unemployment is North Dakota, South Dakota, and Nebraska.
#
# This trend reflects economic disparities across regions, often linked to poverty rates, healthcare access, and job availability. While unemployment is a contributing factor to mental health challenges, further analysis is needed to confirm how closely joblessness correlates with poor mental health days.

# %%
# -- group the data by state and the mean of poor mental health days and drop nan values
state_combined_23_data_df = combined_23_data_df.groupby("state")["Median_Household_Income"].mean()

# -- drop nan values
state_combined_23_data_df.dropna(inplace=True)

# -- reset the index
state_combined_23_data_df = state_combined_23_data_df.reset_index()

# -- create a choropleth map using plotly
labs = {"Median_Household_Income":"Average Mentally Unhealthy Days"}
fig = px.choropleth(
    state_combined_23_data_df,
    locations="state",
    color="Median_Household_Income",
    locationmode="USA-states",
    scope="usa",
    color_continuous_scale="Reds",
    title="Average Median Household Income by State in year 2023 U.S",
    labels=labs)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **(GD: The color bar is mislabeled here.)**

# %% [markdown]
# The Choropleth map median household income across U.S. states in 2023. with darker shades indicating higher income levels and lighter shades representing lower income levels.
#
# The higher-income states with darker shades are District of Columbia, Maryland, Massachusetts, New Hampshire, Alaska, Utah. The lower-income states with lighter shades are Mississippi, West Virginia, Louisiana, Arkansas, Kentucky, New Mexico
#
# This map explains how the income disparities acroos states with higher income concentrated in the Northeast and west while the lower income states are mostly in south.

# %% [markdown]
# The above 3 chloropeth hightlights that strong economic contrast across U.S. states—regions with higher income often have lower unemployment, while states struggling with poverty tend to face job market challenges. The patterns align with broader socioeconomic conditions, but deeper analysis is needed to explore underlying factors like education, cost of living, and industry presence.

# %%
# -- create income_range column by binning median household income into four categories based on quartile
combined_23_data_df["Income_range"] = pd.qcut(combined_23_data_df["Median_Household_Income"], q=4, labels=["Low", "Moderate", "High", "Very High"])

# -- create poverty_range column by binning poverty percentage into four categories basedd on quartile
combined_23_data_df["Poverty_range"] = pd.qcut(combined_23_data_df["Proverty_pct"], q=4, labels=["Low", "Moderate", "High", "Very High"])

# -- drop nan values
pivot = (
    combined_23_data_df
      .groupby(["Income_range","Poverty_range"], observed=True)
      .Poor_Mental_Health_Days
      .mean()
      .unstack()
      .reindex(index=["Low","Moderate","High","Very High"],
               columns=["Low","Moderate","High","Very High"])
)

# --plot
plt.figure(figsize=(6,5))
sns.heatmap(pivot, annot=True, cmap="jet", cbar_kws={"label":"Avg Poor Mental Health Days"})
plt.title("Poor Mental Health Days by Income & Poverty in U.S(2023)")
plt.xlabel("Poverty Range")
plt.ylabel("Income Range")
plt.tight_layout()
plt.show()

# %% [markdown]
# **(GD: We didn't really cover data visualization extensively in this class, but just FYI, rainbow color schemes should almost never be used for a variety of reasons.  This visualization would be more effective with a continuous color scheme.  Great description of how to interpret this plot below.)**

# %% [markdown]
# This Heatmap explains the relations ship between the average income range and the poor mental health days with an additional range of poverty levels for U.S counties in 2023.  Each bar shows a specific range from Low, moderate, high and very high and colors indicate poverty levels low, moderate, high and very high.
#
# The lower the median household income, the higher the poverty and poor mental health days. Similarly, counties with higher median income tend to have lower poverty and fewer poor mental health days, confirming that income and poverty levels significantly affect mental health outcomes.
#
# However, the heatmap shows that raising household income alone is not enough in reducing poverty within income brackets is just as important. Socio-economic factors play a critical role in shaping mental health across U.S. counties.
#
# Additionally, a Very High income range with Moderate poverty levels suggests income disparity within counties. While the median income is high, a portion of the population still faces moderate poverty. This indicates that wealth is unevenly distributed, with some groups benefiting more than others. Addressing poverty alongside income growth is crucial for improving overall well-being.

# %%
# -- Plot the bar plot of Median Household Income range vs Physical Inactivity in year 2023
plt.figure(figsize=(7,6))
sns.barplot(data=combined_23_data_df, x="Income_range", y="Physical_Inactivity_pct")
plt.title("Relationship between the Median Household Income range and Physical Inactivity in year 2023 and 2019")
plt.ylabel("Physical Inactivity Percentages in year 2023")
plt.xlabel("Median Household Income Range")
plt.show()

# %% [markdown]
# The bar plot explains the relation ships between the median household income range vs physical inactivity. The x-axis categorizes the median houehold income ranges into 4 groups low, moderate, high and very high while the y axis has physical inactivity percentages of 2023 year of adults in each income group who reported no leisure-time to physical activity in the past 30 days in life.
#
# Lower income ranges show higher poverty and greater physical inactivity, while moderate income ranges see a noticeable decrease in inactivity. High and Very High income groups have the lowest inactivity levels, at 0.20 and 0.15.
#
# Error bars show the standard error around each group mean, highlighting uncertainty in the estimated inactivity rate. These are determined using statistical measures like standard deviation or standard error, showing the confidence interval around the mean values.This plot demonstrates that economic disadvantage correlates with higher inactivity—insights useful for targeting community exercise programs in low-income areas
#
#
#  This trend helps in understanding the how socio-economic status influences physical health behaviours and the idea that lower income force more barriers to stay active in which it negatively impact both physical and mental health. Understanding this trend helps in designing physical health programs targeted at increasing the physical acitvity in low income communities.

# %% [markdown]
# So far, from the plots, it is evident that the lower the median household income ranges are associated with the higher rates of unemployment, poverty, physical in activity.this means these socio economic facors inpacting the poor emntal health days.

# %%
# -- plot the scatterplot plot to visualie the relation ship between the poor mental health days vs  age groups
plt.figure(figsize=(7,6))

# -- scatter plot fro both Older Age Group and Below 18 Age Group vs. Poor Mental Health Days
sns.scatterplot(data=combined_23_data_df, x="age_above_eq_65_pct", y="Poor_Mental_Health_Days",  label="65+ Age Group")
sns.scatterplot(data=combined_23_data_df, x="Below_age_18_pct", y="Poor_Mental_Health_Days", label="Below 18 Age Group")

plt.title("Older Age vs Below Age 18 Groups vs Poor Mental Health Days (2023)")
plt.xlabel("Age Group Percentage")
plt.ylabel("Average Poor Mental Health Days")
plt.legend()
plt.show()

# %% [markdown]
# The scatter plot explains the relationship between the percentage of population aged 65 or older and poor mental health days in 2023. Each blue dot in the plot represents a data point from the dataset.
#
# for the older age spread of data points shows significant variability, meaning mental health days do not consistently drop as elderly population grows. This indicates that other factors, such as healthcare access and social support, likely play a stronger role.
#
# For the below 18 age group,there is no strong correlation, suggesting that youth percentages follow overall mental health averages rather than influencing them directly.
#
# This plot highlights that age alone does not drive poor mental health days. The wide spread of data points explains the fact that multiple socio-economic factors contribute to mental health at the county level.

# %%
# -- list columns of race
race_cols=['Non-Hispanic_Black_pct', 'American_Indian_or_Alaska Native_pct', 'Asian_pct', 'race_other_pct', 'Hispanic_pct', 'Non-Hispanic_White_pct']

readable_labels = {
    "Non-Hispanic_Black_pct": "Black (Non-Hispanic)",
    "American_Indian_or_Alaska Native_pct": "American Indian / Alaska Native",
    "Asian_pct": "Asian",
    "race_other_pct": "Other Race",
    "Hispanic_pct": "Hispanic",
    "Non-Hispanic_White_pct": "White (Non-Hispanic)"
}

# -- above listed race columns are melted to create column race and their associated values as percentages
combined_health_df = combined_23_data_df.melt(id_vars=["Poor_Mental_Health_Days"], value_vars=race_cols, var_name="Race", value_name="Percentage")
combined_health_df.replace({"Race": readable_labels}, inplace=True)

# -- group the race and BinRace with mean of poor mental health days
group_23_race = combined_health_df.groupby(["Race"])["Poor_Mental_Health_Days"].mean()

# -- reset the index and drop na values
group_23_race = group_23_race.reset_index()
group_23_race.dropna(inplace=True)

# -- plot the bar plot for comparision of poor mental health days by race and percentage bins in year 2023 U.S
plt.figure(figsize=(15,8))
sns.barplot(data=group_23_race, x="Race", y="Poor_Mental_Health_Days")
plt.title("Comparision of Poor Mental Health Days by Race and Race Percentage Bins")
plt.ylabel("Poor Mental Health Days")
plt.xlabel("Race Category")
plt.show()

# %% [markdown]
# This bar plot shows the relationships between the average number of poor mental health days across different racial categories. All the racial categories have poor mental health days between 4 to days adn there is no much difference. **(GD: This might be more effective with a restricted y-axis.)**

# %%
# -- boxplot for metal distress by food access difficulty

combined_23_data_df['Food_Acees_Q'] = pd.qcut(combined_23_data_df["Food_Access_Difficulty"], 4, labels=["Low", "Moderate", "High", "Very High"])
plt.figure(figsize=(8,6))
sns.boxplot(x="Food_Acees_Q", y="Poor_Mental_Health_Days", data=combined_23_data_df)
plt.xlabel("Food Access Difficulty Quartile")
plt.ylabel("Average Mental Unhealthy Days(%)")
plt.title("Average Mental Unhealthy Days Across Food Access Difficulty Quartiles")
plt.show()

# %% [markdown]
# The box shows the relationship between mental health days vary across counties grouped by Food Access Difficulty quartile(0=Low, 1=Moderate, 2=High, 3=Very High). Each box spans the interquartile range middle 50% of counties with horizantal line marking the median poor mental health days and the whiskers extending the most extreme values within 1.5 times of inter quartile range.
#
#
# The food access difficulty increases then the median distress percentage tends to increase, The lowest food access difficulty has the least mental stress while the very high food access difficulty has the highest percentage of mental distress,There is some strong link between food insecurity and mental health struggles

# %%
# -- select required important features
important_feat = [ 'Poor_Mental_Health_Days', 'Median_Household_Income', 'Adult_Smoking_pct',  'Adult_Obesity_pct', 'Access_to_Exercise_Opportunities_pct', 'Severe_Housing_Problems_pct', 'Food_Insecurity_pct', 'Insufficient_Sleep_pct', 'Mental_Health_Providers_ratio', 'Educ_affir_pct', 'Pop_est_val', 'Proverty_pct', 'unemployement_pct', 'Food_Access_Difficulty', 'Demographic_Vulnerability_Ratio']

readable_labels = {
    'Poor_Mental_Health_Days': "Mental Health Days",
    'Median_Household_Income': "Median Income",
    'Adult_Smoking_pct': "Smoking Rate",
    'Adult_Obesity_pct': "Obesity Rate",
    'Access_to_Exercise_Opportunities_pct': "Food Index",
    'Severe_Housing_Problems_pct': "Housing Issues",
    'Food_Insecurity_pct': "Food Insecurity",
    'Insufficient_Sleep_pct': "Sleep Issues",
    'Mental_Health_Providers_ratio': "Mental Health providers",
    'Educ_affir_pct': "Education rate",
    'Pop_est_val': "Population",
    'Proverty_pct': "Poverty Rate",
    'unemployement_pct': "Unemployment",
    'Food_Access_Difficulty': "Food Access",
    'Demographic_Vulnerability_Ratio' : "Demographic Risk"
}

# plot the heat map for above created numeric columns
plt.figure(figsize=(18,18))
corr = combined_23_data_df[important_feat].corr(numeric_only=True)
corr.rename(columns=readable_labels, index=readable_labels, inplace=True)
sns.heatmap(corr, cmap="coolwarm", annot=True, annot_kws={"size": 8})
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.xlabel("Socioeconomic and Health Features")
plt.ylabel("Socioeconomic and Health Features")
plt.title("Heatmap of Correlations between socioeconomic and health factors in year 2023 U.S")
plt.show()

# %% [markdown]
# The heatmap shows correlations between socioeconomic and health factors in U.S. counties for 2023, ranging from -1 (negative) to +1 (positive), with a blue-to-red gradient.
#
# The Poor Mental Health Days correlate with Smoking Rate (0.61), Food Insecurity (0.62), Frequent Mental Distress (0.94), and Insufficient Sleep (0.69) indicating lifestyle and economic stressors impact mental health
#
# Median Household Income negatively correlates with Food Insecurity (-0.75) and Unemployment (-0.87), that higher income reduces financial hardship.
#
# Physical inactivity and food insecurity show the strongest direct contributions to poor mental health.
#
# Higher education and better income act as protective factors, lowering poor mental health days.
#
# The heat map overall gives insights like socio economic factors low income, high poverty annd unemployment are among the strongest predictors of poot mental health days. Higher education levels and income act as protective factors reducing poor mental health days and physical inactivity,
#
# Note: these correlations hide potentially complex relationships in the data.

# %%
# plot the heat map for above created numeric columns


readable_labels = {
    'Poor_Mental_Health_Days_19': "Mental Health Days",
    'Adult_Smoking_pct_19': "Smoking Rate",
    'Adult_Obesity_pct_19': "Obesity Rate",
    'Access_to_Exercise_Opportunities_pct_19': "Food Index",
    'Food_Insecurity_pct_19': "Food Insecurity",
    'Insufficient_Sleep_pct_19': "Sleep Issues",
    'Food_Access_Difficulty': "Food Access",
    'Physical_Inactivity_pct_19': "Physical Inactivity",
    'Excessive_Drinking_pct_19': "Excessive Drinking"
}



corr = analytics_19_df[num_cols_analytics_19].corr(numeric_only=True)
corr.rename(index=readable_labels, columns=readable_labels, inplace=True)


plt.figure(figsize=(18,18))
sns.heatmap(corr, cmap="coolwarm", annot=True, annot_kws={"size": 8})
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.xlabel("Socioeconomic and Health Features")
plt.ylabel("Socioeconomic and Health Features")
plt.title("Heatmap of Correlations between lifestyle and health factors in year 2019 U.S")
plt.show()

# %% [markdown]
# The heatmap of 2019 correlations explains that poor mental health days correlate highly with smoking 0.74 and sleep issues 0.69 and food insecurity 0.61 suggesting counties with higher smoke rates and more sleep problems or greater food hardships also report more mentally unhealthy days
#
#
# Physical inactivity and obesity both show moderate positive ties to mental distress of 0.52 and 0.39 respectively, indicating overlapping lifestyle and health factor burdens.
#
# The food index greater access to healthy food correlates negatively with mental health days of -0.22 and obesity -0.36 hinting that better local food environments may buffer against both poor diet and mental distress.
#
# Note: These correlations hide potentially complex relationships in the data.

# %% [markdown]
# ---

# %% [markdown]
# ### **IV. Methods and Results**

# %% [markdown]
# ###Regression Model

# %% [markdown]
# #### Data Preparation-Regression Model

# %% [markdown]
# First split the data into training and test sets, then on the training data only we handle extreme values (beyond 1.5 times IQR) so a few outliers don't skew our model. Next we standardize every numeric feature to zero mean and unit variance so that all inputs weigh equally and optimization runs smoothly. Finally, we apply those same outlier caps and scaling rules to the test set and use it held completely separate to evaluate real performance and avoid overfitting.
#
# By follwoing these steps we avoid the data leakage problem.

# %%
# -- creating list of input features

feat_cols = [
       'Physical_Inactivity_pct',
       'Median_Household_Income',
       'Below_age_18_pct',
       'age_above_eq_65_pct',
       'Non-Hispanic_Black_pct',
       'American_Indian_or_Alaska Native_pct',
       'Asian_pct',
       'race_other_pct',
       'Hispanic_pct',
       'Non-Hispanic_White_pct',
       'Adult_Smoking_pct',
       'Adult_Obesity_pct',
       'Food_Environment_Index',
       'Access_to_Exercise_Opportunities_pct',
       'Excessive_Drinking_pct',
       'Severe_Housing_Problems_pct',
       'Air_Pollution_Particulate_Matter',
       'Diabetes_Prevalence_pct',
       'Food_Insecurity_pct',
       'Uninsured_pct',
       'Children_in_Single-Parent_Households_pct',
       'Insufficient_Sleep_pct',
       'Mental_Health_Providers_ratio',
       'Educ_affir_pct',
       'Pop_est_val',
       'Proverty_pct',
       'unemployement_pct',
       'Food_Access_Difficulty',
       'Demographic_Vulnerability_Ratio'
      ]

# -- create input features
feat = combined_23_data_df[feat_cols]
feat.columns

# -- create target features
targ = combined_23_data_df["Poor_Mental_Health_Days"]

# %%
# -- compute pearson correlation co-efficient between the input and target features
for col in feat_cols:
    df_pair = feat[[col]].join(targ).dropna()
    xi = df_pair[col].values
    yi = df_pair["Poor_Mental_Health_Days"].values

    cov = np.cov(xi, yi, bias=True)[0, 1]
    corr = cov / (np.std(xi) * np.std(yi))

    plt.figure(figsize=(5, 4))
    plt.scatter(xi, yi, s=10)
    plt.title(f"{col} vs Poor_Mental_Health_Days")
    plt.xlabel(col)
    plt.ylabel("Poor_Mental_Health_Days")
    plt.tight_layout()
    plt.show()
    print(f"{col}: Pearson correlation = {corr:.3f}")
# Out:
# Physical_Inactivity_pct: Pearson correlation = 0.541
# Median_Household_Income: Pearson correlation = -0.463
# Below_age_18_pct: Pearson correlation = -0.073
# age_above_eq_65_pct: Pearson correlation = -0.011
# Non-Hispanic_Black_pct: Pearson correlation = 0.155
# American_Indian_or_Alaska Native_pct: Pearson correlation = -0.007
# Asian_pct: Pearson correlation = -0.205
# race_other_pct: Pearson correlation = -0.067
# Hispanic_pct: Pearson correlation = -0.104
# Non-Hispanic_White_pct: Pearson correlation = -0.009
# Adult_Smoking_pct: Pearson correlation = 0.607
# Adult_Obesity_pct: Pearson correlation = 0.389
# Food_Environment_Index: Pearson correlation = -0.379
# Access_to_Exercise_Opportunities_pct: Pearson correlation = -0.156
# Excessive_Drinking_pct: Pearson correlation = -0.388
# Severe_Housing_Problems_pct: Pearson correlation = 0.117
# Air_Pollution_Particulate_Matter: Pearson correlation = 0.343
# Diabetes_Prevalence_pct: Pearson correlation = 0.509
# ...

# %% [markdown]
#  Looking at the Pearson correlation values, some features show strong correlations ( Insufficient Sleep: 0.689, Food Insecurity: 0.615), while others have weak or negative correlations (e.g., Demographic Vulnerability: -0.054, Mental Health Providers: -0.043).

# %% [markdown]
# **Randomly Split into Train, Test Datasets in 80-20 %ratio**

# %%
# -- creating training and testing set
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, test_size=0.2, random_state=302)

print("length of input features", len(feat))
print("length of feaatures training data",len(feat_tr))
print("length of features testing data",len(feat_te))
# Out:
# length of input features 3183
# length of feaatures training data 2546
# length of features testing data 637

# %% [markdown]
# **Handle Outliers for train data set**

# %%
num_cols_combined_23 = ['Poor_Mental_Health_Days',
       'Physical_Inactivity_pct', 'Median_Household_Income',
       'Below_age_18_pct', 'age_above_eq_65_pct', 'Non-Hispanic_Black_pct',
       'American_Indian_or_Alaska Native_pct', 'Asian_pct', 'race_other_pct',
       'Hispanic_pct', 'Non-Hispanic_White_pct', 'Adult_Smoking_pct',
       'Adult_Obesity_pct', 'Food_Environment_Index',
       'Access_to_Exercise_Opportunities_pct', 'Excessive_Drinking_pct',
       'Severe_Housing_Problems_pct', 'Air_Pollution_Particulate_Matter',
       'Diabetes_Prevalence_pct', 'Food_Insecurity_pct', 'Uninsured_pct',
       'Children_in_Single-Parent_Households_pct', 'Insufficient_Sleep_pct',
       'Mental_Health_Providers_ratio', 'Educ_affir_pct', 'Pop_est_val',
       'Proverty_pct', 'unemployement_pct', 'Food_Access_Difficulty',
       'Demographic_Vulnerability_Ratio']


# -- Plot the histogram for all cols to check presence of outliers in it
fig, axes = plt.subplots(6, 5, figsize=(20, 20))
axes = axes.flatten()

# -- Plot histograms for each numerical column
for ax,col in zip(axes, num_cols_combined_23):
  ax.hist(x=combined_23_data_df[col],bins=30)
  ax.set_title(col, fontsize=9)
  ax.set_xlabel("")

# -- Hide any extra subplots that aren't used
for ax in axes[len(num_cols_combined_23):]:
  ax.axis('off')

plt.show()

# %% [markdown]
# By adding readable labels the plots are shrinking so removed it and displaying as it is.

# %% [markdown]
# Average poor mental health days, physical inactivity, and Under-18% and 65+% age follow roughly bell-shaped distributions, with most counties clustering near the center and only a few extreme cases.
#
# Median household income is right-skewed most counties fall between $40k-$80K, with a few wealthy counties stretching the tail. Most non-White race/ethnicity percentages are highly right-skewed; for instance, many counties report low shares, while a handful have much higher values. Health-behavior measures like adult smoking, obesity, food insecurity, excessive drinking, and insufficient sleep also tend to show right skew, with most values moderate but some counties with unusually high rates. Severe housing problems, uninsured percentages, air pollution, and diabetes prevalence similarly display moderate right skew, though the mental health providers ratio is extremely skewed, indicating that many counties have very few providers while a few have much higher counts.
#
# The Food Environment Index and Access to Exercise each show their own unique patterns. Finally, the population estimate is extremely skewed since most counties have relatively low populations, and only a few urban counties extend into the millions.

# %%
# -- Plot the box plot for all cols to check presence of outliers in it

fig, axes = plt.subplots(5, 5, figsize=(20, 20))
axes = axes.flatten()

# -- plot box plot for each numeric column
for ax,col in zip(axes, num_cols_combined_23):
  sns.boxplot(x=combined_23_data_df[col],ax=ax)
  ax.set_title(col, fontsize=9)
  ax.set_xlabel("")

# -- Hide any extra subplots that aren't used
for ax in axes[len(num_cols_combined_23):]:
  ax.axis('off')

plt.show()

# %% [markdown]
# there are many features are heavily right-skewed with genuine outliers. we observe that from histograms and bar plots. so we apply a log10 transformation adding 1 to handle zeros to mitigate extreme values and achieve a more normal distribution. However, we leave the target variable, "poor mental health days," untransformed due to its minor skew and few outliers, which avoids the need for inverse transformations during post processing. Additionally, we are strictly avoiding data leakage by ensuring that any transformation parameters are derived solely from the training data, preserving raw target values for reliable predictions and easier interpretability

# %%
# -- List of skewed columns that need transformation
skewed_cols = ["Median_Household_Income", "age_above_eq_65_pct", "Non-Hispanic_Black_pct", "American_Indian_or_Alaska Native_pct", "Asian_pct", "race_other_pct", "Hispanic_pct", "Non-Hispanic_White_pct", "Adult_Smoking_pct", "Severe_Housing_Problems_pct", "Air_Pollution_Particulate_Matter", "Diabetes_Prevalence_pct", "Uninsured_pct", "Children_in_Single-Parent_Households_pct", "Insufficient_Sleep_pct", "Mental_Health_Providers_ratio"]

# -- Applying Log Transformation to skewed data columns
combined_23_data_df[skewed_cols] = combined_23_data_df[skewed_cols].apply(lambda x: np.log1p(x))

# -- Plot histograms for those transformed columns
fig, axes = plt.subplots(4, 4, figsize=(20, 20))
axes = axes.flatten()
for ax, col in zip(axes, skewed_cols):
    ax.hist(combined_23_data_df[col], bins=30, edgecolor='black')
    ax.set_title(f"log1p of {col}")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")
plt.tight_layout()
plt.show()
plt.show()

# %% [markdown]
# After applying log10- tranformation all histograms are turned into the normal distributions.
#
# Standardizing features to zero mean and unit variance puts every predictor on the same scale, which helps the model converge faster and makes coefficients directly comparable.
# Many linear models assume that residuals (and sometimes predictors) follow a roughly normal distribution so that hypothesis tests and confidence intervals are valid.
# Transforming skewed variables toward normality also reduces the influence of outliers and helps satisfy those statistical assumptions.

# %% [markdown]
# **Standardize the data**

# %% [markdown]
# Stanndardizing the data using the formula (input_feats-mean)/std_deviation make sures all the features are on the same scale. so that no variable dominates the model. It helps the models to perform better.
#
# Standardizing after splitting the data ensures that the test data remain unseen during the training preventaing the data leakage. If Standardization is done before splitting the mean and standard deviaiton from the whole data set ould lead information about test data leading to biased results. This helps to keep model evaluation fair and realistic when predicting the new data.

# %%
# -- calulating  mean,standard-deviation
train_means = feat_tr.mean(axis=0)
train_stds  = feat_tr.std(axis=0)

# -- standardizing the data by calulating  (x- mean / standard-deviation)
feat_tr = (feat_tr - train_means) / train_stds
feat_te = (feat_te - train_means) / train_stds

# %%
# -- select numerical cols that are standardized
num_cols_standardized = feat_tr.columns

# -- Plot the histogram for all cols to check presence of outliers in it
fig, axes = plt.subplots(5, 5, figsize=(20, 24))
axes = axes.flatten()

# -- Plot histograms for each numerical column
for ax,col in zip(axes[:22], num_cols_standardized):
  ax.hist(x=feat_tr[col],bins=30)
  ax.set_title(col, fontsize=9)
  ax.set_xlabel("")

# -- Hide any extra subplots that aren't used
for ax in axes[len(num_cols_standardized):]:
  ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Random Forest Regression**

# %% [markdown]
# I chose Random Forest Regression for my county-level mental health dataset because it naturally handles non-linear relationships and mixed data types without forcing a linear dependency between predictors and the outcome. My EDA revealed a mix of strong, moderate, and even negative Pearson correlations across various socio-economic and health-behavior factors, and Random Forests are flexible enough to incorporate all these predictors without having to pre-specify their relationships. They reduce overfitting by averaging results from many bootstrapped decision trees, which smooths out the noise inherent in smaller counties or areas with extreme values.
#
# Additionally, Random Forests offer built-in mechanisms for feature selection by ranking predictors based on their contribution to reducing error. This is particularly valuable when dealing with multiple variables that might be operating on different scales or have been imputed. The algorithm's robustness to outliers and missing data is another major advantage in my dataset, where genuine extremes in values can otherwise distort individual decision trees.
#
# Moreover, because Random Forests require minimal hyperparameter tuning to achieve solid baseline performance, I can quickly iterate on model development. They also provide internal validation measures, such as out-of-bag error estimates, which help ensure that the model's predictions will generalize well to new data. All these benefits make Random Forest the ideal choice for effectively modeling and understanding the complex relationships present in county-level mental health outcomes.

# %% [markdown]
# ####**Training Random Forest Regression model with default parameters**

# %%
# -- Initialize Random Forest Regressor with a fixed random state 302
rfr = RandomForestRegressor(random_state=302)

# -- Train the model using the standardized training data
rfr.fit(feat_tr, targ_tr)
# Out:
# RandomForestRegressor(random_state=302)

# %%
# -- Predict on training and test sets
pred_tr = rfr.predict(feat_tr)
pred_targ = rfr.predict(feat_te)

# -- Calculate Mean Squared Error (MSE) and R² for test data
test_mse = mean_squared_error(targ_te, pred_targ)
test_r2 = r2_score(targ_te, pred_targ)

print("**************Test Dataset Results******************")
print("Mean Squared Error: {:.2f}".format(test_mse))
print("R2 Score: {:.2f}".format(test_r2))

# -- Calculate Mean Squared Error (MSE) and R² for train data
train_mse = mean_squared_error(targ_tr, targ_tr)
train_r2 = r2_score(targ_tr, pred_tr)

print("**************Train Dataset Results******************")
print("Mean Squared Error {:.2f}".format(train_mse))
print("R2 score {:.2f}".format(train_r2))
# Out:
# **************Test Dataset Results******************
# Mean Squared Error: 0.08
# R2 Score: 0.78
# **************Train Dataset Results******************
# Mean Squared Error 0.00
# R2 score 0.97

# %% [markdown]
# Mean Squared Error (MSE) measures the average squared difference between the actual values and the predicted values. A lower MSE indicates that predictions are closer to actual values.
#
# R2 measures how well the model explains variability in the target variable. A value of 1 indicates a perfect fit, while a lower value suggests weaker predictive power.

# %% [markdown]
# The training performance is (R2= 0.97, MSE = 0.00), but test performance drops  (R² = 0.78, MSE = 0.08).
#
# The model explained 78 percent variance of train data and then when the difference between the them its huge its totally overfitting means the model learning noisy training  data and remembering thats why its not predicting in new data set so result in less test score.

# %%
# -- Extract feature importance values and sort them in descending order
actual_cols = feat_tr.columns
feat_imp = pd.Series(rfr.feature_importances_, index=actual_cols).sort_values(ascending=False)

# -- Display feature importance values
print(feat_imp)

# -- Horizontal bar chart for better readability
plt.figure(figsize=(10, 8))
feat_imp.plot(kind='barh', color='lightcoral')
plt.title("Feature Importance (Horizontal View)")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.grid(axis='x', linestyle="--", alpha=0.5)
plt.show()
# Out:
# Insufficient_Sleep_pct                      0.423739
# Adult_Smoking_pct                           0.137245
# Food_Insecurity_pct                         0.051672
# unemployement_pct                           0.050179
# Uninsured_pct                               0.047136
# Excessive_Drinking_pct                      0.032738
# Physical_Inactivity_pct                     0.031617
# Non-Hispanic_White_pct                      0.021481
# American_Indian_or_Alaska Native_pct        0.017734
# Pop_est_val                                 0.016985
# Air_Pollution_Particulate_Matter            0.015740
# Adult_Obesity_pct                           0.013516
# Diabetes_Prevalence_pct                     0.012185
# Non-Hispanic_Black_pct                      0.012143
# Asian_pct                                   0.011221
# Severe_Housing_Problems_pct                 0.010557
# race_other_pct                              0.009771
# Mental_Health_Providers_ratio               0.009689
# ...

# %% [markdown]
# From the Random Forest Regression model extracted and visualized the feature importances. The  Feature importance explaince how much each input feature contributes to a model prediction. Higher prediction means the feature has a stronger influence on the target varaible.
#
# Bar chart shows that the feature **Insufficient sleep** has the high importance due to its strong corelation with the target variable.
#
# Poor mental health affected by the majorily insufficient sleep and adult smoking and food in security socio economic factors in year 2023.
#
# Hence the feature **Insufficient sleep** has major importance. it is reliable that due to lack of sleep mental issues will rise,

# %% [markdown]
# Removing less important features reduces noise and the risk of overfitting, so the model can focus on the strongest predictors.
# It also makes the model simpler and faster to train, while improving interpretability.
# Finally, dropping redundant or weak features helps avoid multicollinearity and can boost prediction accuracy.
#
# **(GD: Here and below, be careful about your interpretation of these feature importances given that fact that there may be large covariance among them [e.g., see your correlation plots above].)**

# %%
# -- remove featurs that has importance less than 0.005
feat_imp = pd.Series(rfr.feature_importances_, index=actual_cols)
keep = feat_imp[feat_imp > 0.005].index.tolist()
feat_tr = feat_tr[keep]
feat_te = feat_te[keep]

# %%
# -- Compute learning curve with R² scoring at different training sizes
train_sizes, train_score, test_scores =learning_curve(rfr, feat_tr, targ_tr, scoring="r2", train_sizes=np.linspace(0.1,1.0,5))

# -- Calculate mean R² scores across cross-validation folds
train_mean = train_score.mean(axis=1)
test_mean = test_scores.mean(axis=1)


# Plot learning curve for training and test sets
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, 'o--', label="Training Score", color="blue")
plt.plot(train_sizes, test_mean, 's-', label="Test Score", color="red")
plt.title("Learning Curve - Random Forest")
plt.xlabel("Training Set Size")
plt.ylabel("R² Score")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# Learning curve shows how a machine learning model improves with different amounts of training data. It plots training performance vs. test performance, helping to understand overfitting or underfitting.
#
# Model performs too well on training data but struggles with unseen data is the overfiting
#
# Model performs poorly on both training and test data, indicating it hasn't learned enough is the underfititng.
#
# Training and test scores converge, meaning the model generalizes well. is the balanced learning.
#
# The Learning curve shows that the training score is 0.97 and the model fits the training data very well. Test score is 0.78 explain the varaince but it less than the testing accuracy so that the model is overfittng and also from the feature importance the insufficient sleep is highly correlated with target.

# %% [markdown]
# ####**Grid Search Cross validation(cv) to tune hyper param meters of Random Forest Regression Model**

# %%
# -- Perform Grid Search Cross validation(cv) to find best hyper param meters
tuned_parameters = {
   "n_estimators": [100, 150, 180, 200],
   "max_depth": [6, 10, 20, 30],
   "min_samples_leaf": [6, 10, 15, 20],
   "min_samples_split": [2, 5, 10]
}

# -- 5-fold Cross Validation
rfr_tune = RandomForestRegressor(random_state=302)
cv_tune = GridSearchCV(rfr_tune, param_grid=tuned_parameters, cv=5, scoring='r2', return_train_score=True)
cv_tune.fit(feat_tr, targ_tr)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=302),
#              param_grid={'max_depth': [6, 10, 20, 30],
#                          'min_samples_leaf': [6, 10, 15, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 150, 180, 200]},
#              return_train_score=True, scoring='r2')

# %%
# -- Print the best hyperparameters and best validation R² score
print("Best Parameters:", cv_tune.best_params_)
print("Best Validation Score (R²):", cv_tune.best_score_)
# Out:
# Best Parameters: {'max_depth': 20, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100}
# Best Validation Score (R²): 0.7568043777091973

# %% [markdown]
# These best parameters do not necessarily result in less overfitting, but they provide the highest test score, indicating the best generalization performance so that throught the cv_results_finding the less overfit model parameters

# %%
# -- Check the gap between training and test scores (indicator of overfitting)
results = pd.DataFrame(cv_tune.cv_results_)
param = results.sort_values(['mean_train_score', 'mean_test_score'], ascending=[False, True]).iloc[0]
results['gap'] = results['mean_train_score'] - results['mean_test_score']

# -- Find the least overfitting model configuration
least_overfit = results.sort_values(['gap'])

# -- Print the parameters of the least overfitting model
least_overfit_params = least_overfit.iloc[0]['params']
print("Least Overfit Parameters:", least_overfit_params)

print("Mean Training Score:", least_overfit.iloc[0]['mean_train_score'])
print("Mean Test Score:", least_overfit.iloc[0]['mean_test_score'])
# Out:
# Least Overfit Parameters: {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 5, 'n_estimators': 100}
# Mean Training Score: 0.7746637416778155
# Mean Test Score: 0.700140488328772

# %% [markdown]
# ####**Random Forest with Tuned Hyper Parameters**

# %%
# Train Random Forest model using least overfitting parameters
rfr = RandomForestRegressor(
    random_state=302,
    max_depth=6,
    min_samples_leaf=20,
    n_estimators=100,
    min_samples_split=5
)

# Fit the model on the training dataset
rfr.fit(feat_tr, targ_tr)
# Out:
# RandomForestRegressor(max_depth=6, min_samples_leaf=20, min_samples_split=5,
#                       random_state=302)

# %%
# -- Predict on training and test sets
pred_tr = rfr.predict(feat_tr)
pred_targ = rfr.predict(feat_te)

# -- Calculate Mean Squared Error (MSE) and R² for test data
test_mse = mean_squared_error(targ_te, pred_targ)
test_r2 = r2_score(targ_te, pred_targ)

print("**************Test Dataset Results******************")
print("Mean Squared Error: {:.2f}".format(test_mse))
print("R2 Score: {:.2f}".format(test_r2))

# -- Calculate Mean Squared Error (MSE) and R² for train data
train_mse = mean_squared_error(targ_tr, targ_tr)
train_r2 = r2_score(targ_tr, pred_tr)

print("**************Train Dataset Results******************")
print("Mean Squared Error {:.2f}".format(train_mse))
print("R2 score {:.2f}".format(train_r2))


# -- Extract feature importance values and sort them in descending order
actual_cols = feat_tr.columns
feat_imp = pd.Series(rfr.feature_importances_, index=actual_cols).sort_values(ascending=False)

# -- Display feature importance values
print("**************Feature Importances******************")
print(feat_imp)

# -- Horizontal bar chart for better readability
plt.figure(figsize=(10, 8))
feat_imp.plot(kind='barh', color='lightcoral')
plt.title("Feature Importance (Horizontal View)")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.grid(axis='x', linestyle="--", alpha=0.5)

print("**************Feature Importances plot******************")
plt.show()


# -- Compute learning curve with R² scoring at different training sizes
train_sizes, train_score, test_scores =learning_curve(rfr, feat_tr, targ_tr, scoring="r2", train_sizes=np.linspace(0.1,1.0,5))

# -- Calculate mean R² scores across cross-validation folds
train_mean = train_score.mean(axis=1)
test_mean = test_scores.mean(axis=1)


# Plot learning curve for training and test sets
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, 'o--', label="Training Score", color="blue")
plt.plot(train_sizes, test_mean, 's-', label="Test Score", color="red")
plt.title("Learning Curve - Random Forest")
plt.xlabel("Training Set Size")
plt.ylabel("R² Score")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.5)
print("**************Learning Curve******************")
plt.show()
# Out:
# **************Test Dataset Results******************
# Mean Squared Error: 0.11
# R2 Score: 0.71
# **************Train Dataset Results******************
# Mean Squared Error 0.00
# R2 score 0.77
# **************Feature Importances******************
# Insufficient_Sleep_pct                      0.553179
# Adult_Smoking_pct                           0.169765
# Food_Insecurity_pct                         0.056809
# unemployement_pct                           0.048411
# Uninsured_pct                               0.043672
# Physical_Inactivity_pct                     0.025244
# Excessive_Drinking_pct                      0.021329
# Non-Hispanic_White_pct                      0.016692
# Pop_est_val                                 0.010799
# Adult_Obesity_pct                           0.005923
# Air_Pollution_Particulate_Matter            0.005861
# American_Indian_or_Alaska Native_pct        0.005796
# Severe_Housing_Problems_pct                 0.004965
# ...

# %% [markdown]
# **------------Test Dataset Results-----------**
#
# The Mean Squared Error (MSE) measures the average squared difference between predicted and actual values. A lower MSE indicates better accuracy, and here the score is 0.11, showing that the model provides reasonably accurate predictions.
#
# The R² Score evaluates how well the model explains target variance. A score of 0.71 means the model explains 71% of the variance in the test dataset, indicating a good fit but with room for improvement in generalization.
#
# **------------Train Dataset Results-----------**
#
# The Mean Squared Error (MSE) for the training set is 0.00, meaning the model fits the training data almost perfectly. This can indicate overfitting, where the model memorizes training patterns instead of learning general trends.
#
# The R² Score of 0.77 suggests the model explains 77% of the variance in the training dataset. While high, the slight drop in test R² indicates the model may not generalize as well to unseen data.
#
#
# Overfitting: The training dataset explains 77% of variance and the testing dataset explains the 70% varaicne. It is a overfit model.
#
# **------------Feature Importance-----------**
#
# The strongest predictor is Insufficient Sleep with a feature importance of 0.55, followed by Adult Smoking and Food Security.
#
# The model generalizes the data well, and it is reasonable to infer that lack of sleep contributes significantly to mental health issues.
#
#
# **------------Learning Curve  Results-----------**
#
# The learning curve shows how performance evolves with different training set sizes.
#
# The training score (blue line) remains consistently high, indicating the model fits well to training data.
#
# The test score (red line) improves with increasing data size but remains lower than the training score, suggesting some overfitting.
#
# A small gap between training and test scores indicates good learning, but excessive training performance with lower test scores can suggest limited generalization.

# %%
# -- Calculate prediction errors (difference between actual and predicted values)
errors = pred_targ - targ_te

# -- Create scatter plot of actual vs. predicted values, colored by errors
plt.figure(figsize=(6,6))
plt.scatter(targ_te, pred_targ, alpha=0.6, c=errors, cmap="coolwarm")

# -- Set axis limits based on min/max values in actual and predicted data
lims = [min(targ_te.min(), pred_targ.min()), max(targ_te.max(), pred_targ.max())]

# -- Plot predictions vs actual values)
plt.plot(lims, lims, 'k--', linewidth=1)
plt.title("Predictions vs. Actual Poor Mental Health Days in the U.S. (2023, County Level)")
plt.ylabel("Predicted Poor Mental Health Days")
plt.xlabel("Actual Poor Mental Health Days")
plt.xlim(lims)
plt.ylim(lims)
plt.show()

# %% [markdown]
# **(GD: The color-coding on this plot isn't necessary and possibly even detracts a bit in this case.)**

# %% [markdown]
# This scatter plots each county's actual poor mental health days (x-axis) against the model's predicted days (y-axis). The dashed diagonal is the “perfect prediction” line—any point on it would mean predicted = actual. Most points hug that diagonal, indicating our model captures the broad trend, but we can spot two biases:
#
# Over-prediction at low values (points above the line on the left)
#
# Under-prediction at high values (points below the line on the right)
#
# The red-to-blue color scale encodes the residuals (red = predicted > actual, blue = predicted < actual), making it easy to see where the model deviates most.

# %% [markdown]
# ###Classification Model

# %% [markdown]
# #####**Data preparation for classification model**

# %%
# --  calculate the changes in 2023 and 209 data sets
diff_2019_2023 = pd.DataFrame()
diff_2019_2023["Poor_Mental_Health_Days"] = (combined_23_data_df["Poor_Mental_Health_Days"] - analytics_19_df["Poor_Mental_Health_Days_19"])
diff_2019_2023["Physical_Inactivity_pct"] = (combined_23_data_df["Physical_Inactivity_pct"] - analytics_19_df["Physical_Inactivity_pct_19"])
diff_2019_2023["Adult_Obesity_pct"] = (combined_23_data_df["Adult_Obesity_pct"] - analytics_19_df["Adult_Obesity_pct_19"])
diff_2019_2023["Access_to_Exercise_Opportunities_pct"] = (combined_23_data_df["Access_to_Exercise_Opportunities_pct"] - analytics_19_df["Access_to_Exercise_Opportunities_pct_19"])
diff_2019_2023["Excessive_Drinking_pct"] = (combined_23_data_df["Excessive_Drinking_pct"] - analytics_19_df["Excessive_Drinking_pct_19"])
diff_2019_2023["Food_Insecurity_pct"] = (combined_23_data_df["Food_Insecurity_pct"] - analytics_19_df["Food_Insecurity_pct_19"])
diff_2019_2023["Adult_Smoking_pct"] = (combined_23_data_df["Adult_Smoking_pct"] - analytics_19_df["Adult_Smoking_pct_19"])
diff_2019_2023["Insufficient_Sleep_pct"] = (combined_23_data_df["Insufficient_Sleep_pct"] - analytics_19_df["Insufficient_Sleep_pct_19"])

# %% [markdown]
# **Handle NaN values**

# %%
diff_2019_2023.isna().sum()
# Out:
# Poor_Mental_Health_Days                 12
# Physical_Inactivity_pct                 12
# Adult_Obesity_pct                       12
# Access_to_Exercise_Opportunities_pct    12
# Excessive_Drinking_pct                  12
# Food_Insecurity_pct                     12
# Adult_Smoking_pct                       12
# Insufficient_Sleep_pct                  12
# dtype: int64

# %% [markdown]
# These 12 rows contain only missing
# values, so it's best to drop them they add no information to our analysis.

# %%
# Drop all rows with any NaN
diff_2019_2023 = diff_2019_2023.dropna().reset_index(drop=True)

diff_2019_2023.isna().sum()
# Out:
# Poor_Mental_Health_Days                 0
# Physical_Inactivity_pct                 0
# Adult_Obesity_pct                       0
# Access_to_Exercise_Opportunities_pct    0
# Excessive_Drinking_pct                  0
# Food_Insecurity_pct                     0
# Adult_Smoking_pct                       0
# Insufficient_Sleep_pct                  0
# MH_change_Class                         0
# MH_change_Code                          0
# dtype: int64

# %% [markdown]
# There is no missing values

# %% [markdown]
# **Handle Duplicate rows**

# %%
#-- check for duplicates
Duplicates = diff_2019_2023[diff_2019_2023.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [fipscode, year, Poor_Mental_Health_Days, Physical_Inactivity_pct, Median_Household_Income, Below_age_18_pct, age_above_eq_65_pct, Non-Hispanic_Black_pct, American_Indian_or_Alaska Native_pct, Asian_pct, race_other_pct, Hispanic_pct, Non-Hispanic_White_pct, Adult_Smoking_pct, Adult_Obesity_pct, Food_Environment_Index, Access_to_Exercise_Opportunities_pct, Excessive_Drinking_pct, Severe_Housing_Problems_pct, Air_Pollution_Particulate_Matter, Diabetes_Prevalence_pct, Food_Insecurity_pct, Uninsured_pct, Children_in_Single-Parent_Households_pct, Insufficient_Sleep_pct, Mental_Health_Providers_ratio, Educ_affir_pct, Pop_est_val, Proverty_pct, state_final, unemployement_pct, Food_Access_Difficulty, Demographic_Vulnerability_Ratio]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# No duplicate rows are present

# %%
diff_2019_2023.describe()
# Out:
#        Poor_Mental_Health_Days  Physical_Inactivity_pct  Adult_Obesity_pct  \
# count              3182.000000              3182.000000        3182.000000
# mean                  0.862899                 0.000298           0.041169
# std                   0.601416                 0.054237           0.050922
# min                  -2.110244                -0.205000          -0.167000
# 25%                   0.499140                -0.035750           0.010000
# 50%                   0.883456                -0.002000           0.042000
# 75%                   1.248756                 0.034000           0.074000
# max                   3.234030                 0.231000           0.225000
#
#        Access_to_Exercise_Opportunities_pct  Excessive_Drinking_pct  \
# count                           3182.000000             3182.000000
# mean                              -0.020230                0.016581
# std                                0.298726                0.030737
# ...

# %% [markdown]
# Changes in year 2019 and 2023, the average county saw an increase of about 0.86 poor mental health days of median 0.88 with some counties jumping over 3 days.
#
# Adult obesity rates climbed by roughly 4 percentage points on average 50th percentage while excessive drinking rose by about 1.6 percentage.
#
# Smoking prevalence ticked up by 2.1 percentage and insuffucient sleep by 1.4 percentage. where the smoking and sleep worsened slightly.
#
# The access to exercise opputunities dipped slightly mean 0.02 and food insecurity fell about 1.3 percentage.
#
# Overall mental health and obesity show the largest upward shifts while inactive stayed level and food insecurity measures actually got a bit better.

# %%
# -- list numeric columns for change values
num_cols = [c for c in diff_2019_2023.select_dtypes('float64').columns]

# -- draw boxplot for each change variable
fig, axes = plt.subplots(2, 4, figsize=(10, 9))
axes = axes.flatten()

# -- plot box plot for each numeric column
for ax,col in zip(axes, num_cols):
  sns.boxplot(x=diff_2019_2023[col],ax=ax)
  ax.set_title(col, fontsize=9)
  ax.set_xlabel("")

# -- Hide any extra subplots that aren't used
for ax in axes[len(num_cols):]:
  ax.axis('off')

plt.show()

# %% [markdown]
# These eight boxplots show each county indicators **Poor Mental Health Days** and **Access to Exercise Opportunities** have the widest spreads, meaning counties differ most on those measures. **Physical Inactivity**, **Insufficient Sleep**, and **Excessive Drinking** cluster tightly around the mean, indicating little variation across counties. Outlier dots mark counties with unusually high or low values.

# %%
# -- Plot the histogram for all cols to check presence of outliers in it
fig, axes = plt.subplots(2, 4, figsize=(10, 9))
axes = axes.flatten()

# -- Plot histograms for each numerical column
for ax,col in zip(axes, num_cols):
  ax.hist(x=diff_2019_2023[col],bins=30,edgecolor='black')
  ax.set_title(col, fontsize=9)
  ax.set_xlabel("")

# -- Hide any extra subplots that aren't used
for ax in axes[len(num_cols):]:
  ax.axis('off')

plt.show()

# %% [markdown]
# All eight histograms of the county metrics form roughly bell-shaped distributions centered at zero, showing the data were successfully standardized. Poor Mental Health Days and Food Insecurity exhibit a modest right skew—more counties suffer above-average burdens there. Adult Smoking and Adult Obesity lean slightly left, meaning more counties are below the mean for those risk factors. Excessive Drinking, Insufficient Sleep, and Physical Inactivity are tightly peaked around zero, indicating comparatively low variation. Access to Exercise Opportunities is fairly symmetric but a bit flatter, reflecting its greater county-to-county spread.

# %%
# Define bins to categorize changes in Poor Mental Health Days: values <= 0.1 are considered "Improved",
# while values > 0.1 are labeled as "Worsened".
bins = [-np.inf, 0.1, np.inf]
labels = ["Improved", "Worsened"]

# Use pd.cut to assign a class label based on the defined bins to each observation
diff_2019_2023["MH_change_Class"] = pd.cut(diff_2019_2023['Poor_Mental_Health_Days'], bins=bins, labels=labels)

# Convert 'MH_change_Class' to an ordered categorical type using predefined labels (Improved, Worsened) for consistent ordering.
diff_2019_2023['MH_change_Class'] = pd.Categorical(
    diff_2019_2023['MH_change_Class'],
    categories=labels,
    ordered=True
)

# Assign numerical codes to the categorical classes for easier analysis; then print the value counts.
diff_2019_2023['MH_change_Code'] = diff_2019_2023['MH_change_Class'].cat.codes
print(diff_2019_2023[['MH_change_Class','MH_change_Code']].value_counts())
# Out:
# MH_change_Class  MH_change_Code
# Worsened         1                 2896
# Improved         0                  286
# Name: count, dtype: int64

# %% [markdown]
# Our improved vs. worsened label is very unbalanced: most counties are “worsened” and only a few are “improved.” If we just split and train, the model can guess “worsened” all the time and still be right most of the time.
#
# To fix this, we can try three things:
#
# 1. Drop some “worsened” examples so both groups are the same size.
#
#    * It is easy but we throw away real data.
#
# 2. Make new “improved” examples from the ones we have (SMOTE).
#
#    * We keep all the real data and add more “improved” cases.
#    * But the new ones might be noisy if the groups overlap.
#
# 3. Tell the model to care more about “improved” errors (class weights).
#
#    * We do not remove or invent data.
#    * The model learns that missing an “improved” case is worse.
#
# Dropping cases left us too little data, so we should use SMOTE to boost the “improved” group and also give extra weight to “improved” errors. This way the model sees enough “improved” examples and learns not to ignore them.

# %%
# -- creating list of input features
feat_cols = [
       'Physical_Inactivity_pct',
       'Adult_Smoking_pct',
       'Adult_Obesity_pct',
       'Access_to_Exercise_Opportunities_pct',
       'Excessive_Drinking_pct',
       'Food_Insecurity_pct',
       'Insufficient_Sleep_pct',
      ]

# -- create input features
feat = diff_2019_2023[feat_cols]
feat.columns

# -- create target features
targ = diff_2019_2023['MH_change_Code']

# %%
targ.value_counts()
# Out:
# MH_change_Code
# 1    2896
# 0     286
# Name: count, dtype: int64

# %% [markdown]
# **Split into Train and Test Data sets**

# %%
# -- creating training and testing set
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, test_size=0.2, random_state=302)

print("length of feaatures training data",len(feat_tr))
print("length of features testing data",len(feat_te))
print("length of inout features", len(feat))
# Out:
# length of feaatures training data 2545
# length of features testing data 637
# length of inout features 3182

# %% [markdown]
# **Oversampling the data using smote method**

# %%
print("Before oversample:", targ_tr.value_counts().to_dict())

# Apply SMOTE to only the training data
smote = SMOTE(random_state=302)
feat_tr_res, targ_tr_res = smote.fit_resample(feat_tr, targ_tr)

feat_tr = feat_tr_res
targ_tr = targ_tr_res
print("After oversample:", targ_tr.value_counts().to_dict())
# Out:
# Before oversample: {1: 2320, 0: 225}
# After oversample: {1: 2320, 0: 2320}

# %% [markdown]
# SMOTE (Synthetic Minority Over-sampling Technique)
# Generates new minority-class examples by interpolating between existing ones, balancing the dataset without simple duplication.
#  Helps the model learn decision boundaries in regions where the minority class is under-represented.
#
# we apply only to the training set
# Prevents synthetic data from leaking into validation or test splits, so performance estimates remain unbiased.
# Ensures the classifier sees equal class representation during training, improving its ability to detect the minority class.

# %%
print("Train class counts:")
print(targ_tr.value_counts())

print("\nTrain class proportions:")
print(targ_tr.value_counts(normalize=True).round(3))

print("\nTest class counts:")
print(targ_te.value_counts())

print("\nTest class proportions:")
print(targ_te.value_counts(normalize=True).round(3))
# Out:
# Train class counts:
# MH_change_Code
# 1    2320
# 0    2320
# Name: count, dtype: int64
#
# Train class proportions:
# MH_change_Code
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
# Test class counts:
# MH_change_Code
# 1    576
# 0     61
# Name: count, dtype: int64
#
# Test class proportions:
# MH_change_Code
# 1    0.904
# 0    0.096
# Name: proportion, dtype: float64

# %% [markdown]
# After SMOTE, the **training set** is perfectly balanced with 2,320 examples of each class (50 % MH_change_Code = 1 and 50 % MH_change_Code = 0).
#  The **test set** remains imbalanced at 576 vs. 61 examples, or about 90.4 % class 1 and 9.6 % class 0.

# %% [markdown]
# ####Decision Tree Classifiation with default Hyper Parameters

# %% [markdown]
# Because our test labels are still about 80% one class and 20% the other, we chose a Decision Tree classifier: its hierarchical splits (and easy class-weighting) naturally focus on minority cases without requiring extra sampling. Unlike many models, trees need no feature scaling, handle mixed data types and non-linear patterns out of the box, and produce an interpretable, rule-based structure that's simpler to explain than black-box algorithms. And also we can give the custom weights to handle the hyper parameters
#
# In addition, Decision Trees are computationally efficient and easy to implement, making trees are ideal for quick prototyping and iterative model development. These inherent capability to handle missing values and outliers simplifies data preprocessing. Trees also capture complex feature interactions without the need for extensive feature engineering and provide clear insights through feature importance metrics. Furthermore, trees visual structure enables straightforward communication of decision logic how the model make the deciion and which is the root node.

# %%
# -- fit decision tree model
dtc = DecisionTreeClassifier(random_state=302)
dtc.fit(feat_tr_res,targ_tr_res)
# Out:
# DecisionTreeClassifier(random_state=302)

# %%
# -- fit a decision tree classifier on the TRAINING data
dtc.fit(feat_tr, targ_tr)

# -- assess the accuracy on the TRAINING data
pred_tr  = dtc.predict(feat_tr)
acc_tr   = accuracy_score(targ_tr, pred_tr)
print("training accuracy = {0:.3f}".format(acc_tr))

# -- assess the accuracy on the TESTING data
pred_te  = dtc.predict(feat_te)
acc_te   = accuracy_score(targ_te, pred_te)
print("testing  accuracy = {0:.3f}".format(acc_te))
# Out:
# training accuracy = 1.000
# testing  accuracy = 0.823

# %% [markdown]
# * Training accuracy = 1.000 means the tree has perfectly memorized the training set—classic overfitting.
# * Testing accuracy = 0.824 shows decent generalization but a less drop.
#
# Classification accuracy is the percentage of instances whose predicted labels exactly match their true labels out of all instances evaluated. Because our data set is imabalanced we can't reliable on the accuracy metric. So further proceeding with evaluation metric precision and recall.

# %%
#-- calculate the precion, recall and f1-score
prec_tr  = precision_score(targ_tr, pred_tr, average='macro')
recall_tr= recall_score(targ_tr, pred_tr, average='macro')
f1_tr= f1_score(targ_tr, pred_tr, average='macro')

print("\n -----training scores-----")
print("precison score = {0:.3f}".format(prec_tr))
print("recall score = {0:.3f}".format(recall_tr))
print("f1 score = {0:.3f}".format(f1_tr))

prec_te = precision_score(targ_te, pred_te, average='macro')
recall_te = recall_score(targ_te, pred_te, average='macro')
f1_te = f1_score(targ_te, pred_te, average='macro')

print("\n -----testing scores-----")
print("precison score = {0:.3f}".format(prec_te))
print("recall score = {0:.3f}".format(recall_te))
print("f1 score = {0:.3f}".format(f1_te))
# Out:
#  -----training scores-----
# precison score = 1.000
# recall score = 1.000
# f1 score = 1.000
#
#  -----testing scores-----
# precison score = 0.604
# recall score = 0.675
# f1 score = 0.622

# %% [markdown]
# precision tells me how often the model “improved” predictions are actually right.
#
#  recall tells me how many of the real improved counties the model manages to catch.
#
#   f1 mixes the two into one score so i can see overall how well it balances precision and recall.
#
# on the training set precision, recall and f1 all hit 1.0 (it memorized every example). on the test set precision drops to about 0.61, recall to about 0.67 and f1 to about 0.63—so it still finds most improved counties but makes more mistakes and misses more cases on new data.

# %%
# -- display the confusion matrix
cm_te = confusion_matrix(targ_te, pred_te, labels=[0,1])
disp_te = ConfusionMatrixDisplay(confusion_matrix=cm_te, display_labels=["Improved(0)","Worsened(1)"])
fig,ax=plt.subplots(figsize=(5,5))
disp_te.plot(cmap="Blues", ax=ax, colorbar=False)
ax.set_title("confusion matrix- test")
plt.show()

# %% [markdown]
# Test set 30 true “improved” counties were correctly labeled improved (top-left), but 31 true improved were mis-classified as worsened (top-right).
#
# 494 true “worsened” counties were correctly labeled worsened (bottom-right), and 80 were mistakenly called improved (bottom-left).
#
# so out of 61 actual improved counties, i only got 30 right (and missed 82), whereas out of 576 worsened counties i nailed 496 that explains why the model's recall and precision on the minority “improved” class are so much lower than for the majority “worsened” class.
#
#
# This model is not reliable because of the overfitting it majorily predict it ahs worsened not 50% cases it ma predict improved. Its too overfititng and not reliable in most cases real time

# %%
# -- visualize the tree
dtr_data = tree.export_graphviz(dtc, out_file=None, filled=True, rounded=False,
                      special_characters=True, max_depth=3,
                      feature_names=feat.columns, class_names=["0", "1"])
graph = graphviz.Source(dtr_data)
graph

# %% [markdown]
# The model first looks at Adult_Smoking_pct, splitting counties into those with very low smoking rates (≤0.017) versus the rest. That initial cut already groups most low-smoking counties toward “improved” and high-smoking toward “worsened.” Among the low-smoking branch, it then checks Food_Insecurity_pct, sending counties with the least food insecurity further down the “improved” path, while those with higher insecurity flip back toward “worsened.” Each split is chosen to maximize purity (i.e. reduce Gini impurity), carving out the biggest class imbalances at each step so the tree can make clear, rule-based predictions.

# %% [markdown]
# Hence due to overfitting and its predicting majorily the worsened and 50% cases the improved. this is because of the imbalanced data so that trying with other method class weigthage to balance the data and predict the target

# %% [markdown]
# ####**Using the Class weightage method**

# %% [markdown]
# Class weighting tells the tree to treat each “improved” sample as five times more important than a “worsened” one when finding splits, so misclassifying an improved county incurs a much bigger penalty. This skews the Gini-impurity calculations toward better handling of the minority class without changing the data itself.
#
#
# I even tried with multiple weights dictionaty and this  5,1 sets gives less overfiting score and classifying the data well

# %%
weight_dict = {
    0: 5,   # Improved
    1: 1    # Worsened
}


# -- fit decision tree model
dtc = DecisionTreeClassifier(random_state=302,class_weight=weight_dict)
dtc.fit(feat_tr_res,targ_tr_res)
# Out:
# DecisionTreeClassifier(class_weight={0: 5, 1: 1}, random_state=302)

# %%
# -- fit a decision tree classifier on the TRAINING data
dtc.fit(feat_tr, targ_tr)

# -- assess the accuracy on the TRAINING data
pred_tr  = dtc.predict(feat_tr)
acc_tr   = accuracy_score(targ_tr, pred_tr)
print("training accuracy = {0:.3f}".format(acc_tr))

# -- assess the accuracy on the TESTING data
pred_te  = dtc.predict(feat_te)
acc_te   = accuracy_score(targ_te, pred_te)
print("testing  accuracy = {0:.3f}".format(acc_te))

prec_tr  = precision_score(targ_tr, pred_tr, average='macro')
recall_tr= recall_score(targ_tr, pred_tr, average='macro')
f1_tr= f1_score(targ_tr, pred_tr, average='macro')

print("\n -----training scores-----")
print("precison score = {0:.3f}".format(prec_tr))
print("recall score = {0:.3f}".format(recall_tr))
print("f1 score = {0:.3f}".format(f1_tr))

prec_te = precision_score(targ_te, pred_te, average='macro')
recall_te = recall_score(targ_te, pred_te, average='macro')
f1_te = f1_score(targ_te, pred_te, average='macro')

print("\n -----testing scores-----")
print("precison score = {0:.3f}".format(prec_te))
print("recall score = {0:.3f}".format(recall_te))
print("f1 score = {0:.3f}".format(f1_te))

#--plot the confusion matrix
cm_te = confusion_matrix(targ_te, pred_te, labels=[0,1])
disp_te = ConfusionMatrixDisplay(confusion_matrix=cm_te, display_labels=["Improved(0)","Worsened(1)"])

fig,ax=plt.subplots(figsize=(5,5))
disp_te.plot(cmap="Blues", ax=ax, colorbar=False)
ax.set_title("confusion matrix- test")
plt.show()
# Out:
# training accuracy = 1.000
# testing  accuracy = 0.826
#
#  -----training scores-----
# precison score = 1.000
# recall score = 1.000
# f1 score = 1.000
#
#  -----testing scores-----
# precison score = 0.601
# recall score = 0.662
# f1 score = 0.618

# %% [markdown]
# The model memorizes the training data perfectly but only reaches 82.6 % accuracy on the test set—correctly flagging 498 of 576 worsened counties and 28 of 61 improved ones—resulting in a macro precision of 0.601, recall of 0.662, and F1 score of 0.618.
#
#
# Using average=macro just means I take the precision or recall or F1 for each class on its own “improved” and “worsened” and then average those two numbers equally, so each class counts the same regardless of how big it is.

# %%
# -- visualize the tree
dtr_data = tree.export_graphviz(dtc, out_file=None, filled=True, rounded=False,
                      special_characters=True, max_depth=3,
                      feature_names=feat.columns, class_names=["0", "1"])
graph = graphviz.Source(dtr_data)
graph

# %% [markdown]
# Root node: splits on Adult_Smoking_pct ≤ 0.02, creating much purer child groups (Gini drops from 0.5 to 0.278).
#
# Left child (low-smoking counties) then splits on Food_Insecurity_pct ≤ -0.034, further isolating the “improved” class (Gini = 0.145).
#
# Right child continues splitting on obesity or other features to separate “worsened.”
# Each box reports the impurity, sample count, class-value breakdown, and the majority-class prediction.
# By this we can understand the majority the root node adult smoking oercent is targeting the output

# %% [markdown]
# Removing the feature Adult Smoking pct from both the train and test data set and checking how the model performs and tuning with the hyper parameters.

# %%
feat_tr.drop(columns=["Adult_Smoking_pct"], inplace=True)
feat_tr.columns
# Out:
# Index(['Physical_Inactivity_pct', 'Adult_Obesity_pct',
#        'Access_to_Exercise_Opportunities_pct', 'Excessive_Drinking_pct',
#        'Food_Insecurity_pct', 'Insufficient_Sleep_pct'],
#       dtype='object')

# %%
feat_te.drop(columns=["Adult_Smoking_pct"], inplace=True)
feat_te.columns
# Out:
# Index(['Physical_Inactivity_pct', 'Adult_Obesity_pct',
#        'Access_to_Exercise_Opportunities_pct', 'Excessive_Drinking_pct',
#        'Food_Insecurity_pct', 'Insufficient_Sleep_pct'],
#       dtype='object')

# %% [markdown]
# ####**Hyper parameters tuning using the Grid Search CV method**

# %% [markdown]
# Tuning tree hyperparameters via GridSearchCV helps to strike a better bias-variance balance than the default settings:
#
# Control model complexity: by testing different max_depth, min_samples_leaf and min_samples_split values, we prevent the tree from growing too deep (overfitting noise) or staying too shallow (underfitting signal).
#
# GridSearchCV runs five-fold CV for each parameter combination, evaluates them on our minority-class recall scorer, and picks the one that best catches “improved” counties without memorizing the training data.
#
# Better generalization when compared to the one-shot default tree, the tuned model usually shows higher recall on unseen data and less disparity between training and test scores, so it reliably identifies more of those rare improved cases in new counties.

# %%
recall0 = make_scorer(recall_score, pos_label=0)

# -- select the hyper parameters to tune and the values to try
tuned_parameters = {
   "max_depth": [20, 30, 40, 50],
   "min_samples_leaf": [10, 15, 20, 30],
   "min_samples_split": [2, 5, 10]
}

# -- perform Grid Search
dtc_tune = DecisionTreeClassifier(random_state=302)
cv_tune = GridSearchCV(dtc_tune, tuned_parameters, cv=5, scoring=recall0, verbose=1)
cv_tune.fit(feat_tr,targ_tr)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=302),
#              param_grid={'max_depth': [20, 30, 40, 50],
#                          'min_samples_leaf': [10, 15, 20, 30],
#                          'min_samples_split': [2, 5, 10]},
#              scoring=make_scorer(recall_score, response_method='predict', pos_label=0),
#              verbose=1)

# %%
# -- print out params with the highest score
cv_tune.best_params_
# Out:
# {'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}

# %% [markdown]
# After testing 48 different combinations with 5-fold CV to maximize recall on the “improved” class, cv_tune.best_params_ reports that the optimal settings are max_depth=20, min_samples_leaf=10, and min_samples_split=2.
#
# We then create a fresh DecisionTreeClassifier using those tuned hyperparameters.
#
# Finally, we fit this tuned tree on the full training set so it learns splits under the parameters shown to give the best minority-class recall.

# %%
# -- fit decision tree model
dtc = DecisionTreeClassifier(random_state=302, max_depth=20, min_samples_leaf=10, min_samples_split=2)
dtc.fit(feat_tr,targ_tr)
# Out:
# DecisionTreeClassifier(max_depth=20, min_samples_leaf=10, random_state=302)

# %%
# -- fit a decision tree classifier on the TRAINING data
dtc.fit(feat_tr, targ_tr)

# -- assess the accuracy on the TRAINING data
pred_tr  = dtc.predict(feat_tr)
acc_tr   = accuracy_score(targ_tr, pred_tr)
print("training accuracy = {0:.3f}".format(acc_tr))

# -- assess the accuracy on the TESTING data
pred_te  = dtc.predict(feat_te)
acc_te   = accuracy_score(targ_te, pred_te)
print("testing  accuracy = {0:.3f}".format(acc_te))
# Out:
# training accuracy = 0.894
# testing  accuracy = 0.763

# %% [markdown]
# Training vs. testing accuracy it drops to 0.89 on train and 0.76 on test, so the model back from perfect memorization and improved its generalization balance.

# %%
prec_tr = precision_score(targ_tr, pred_tr)
recall_tr = recall_score(targ_tr, pred_tr)
f1_tr = f1_score(targ_tr, pred_tr)

print("\n -----training scores-----")
print("precison score = {0:.3f}".format(prec_tr))
print("recall score = {0:.3f}".format(recall_tr))
print("f1 score = {0:.3f}".format(f1_tr))

prec_te = precision_score(targ_te, pred_te)
recall_te = recall_score(targ_te, pred_te)
f1_te = f1_score(targ_te, pred_te)

print("\n -----testing scores-----")
print("precison score = {0:.3f}".format(prec_te))
print("recall score = {0:.3f}".format(recall_te))
print("f1 score = {0:.3f}".format(f1_te))
# Out:
#  -----training scores-----
# precison score = 1.000
# recall score = 1.000
# f1 score = 1.000
#
#  -----testing scores-----
# precison score = 0.938
# recall score = 0.865
# f1 score = 0.900

# %% [markdown]
# the training set my model still perfectly classifies every county (precision, recall and F1 all 1.000), which usually means it's memorized the data.
#
# on the test set:
#
# precision = 0.938 means that when the model predicts “worsened,” it's correct 93.8 % of the time
#
# recall = 0.865 means it catches 86.5 % of all the true “worsened” counties
#
# F1 = 0.900 is the  balance of those two, showing it maintains strong overall performance out of sample.

# %%
cm_te = confusion_matrix(targ_te, pred_te, labels=[0,1])
disp_te = ConfusionMatrixDisplay(confusion_matrix=cm_te, display_labels=["Not Worsened(0)", "Worsened (1)"])

fig,ax=plt.subplots(figsize=(5,5))
disp_te.plot(cmap="Blues", ax=ax, colorbar=False)
ax.set_title("confusion matrix- test")
plt.show()

# %% [markdown]
# Confusion matrix explains of the 61 true “improved” counties, we now catch 38 (vs. 23 before) and miss 15; of the 576 “worsened,” we still nail 448 but wrongly flag 128 as improved.
#
#  hyperparameter tuning boosted recall on the minority class (now 0.70 vs. 0.67) at the expense of overall accuracy and precision, reflecting the classic trade-off between catching more rare cases and introducing more false alarms.

# %%
# -- visualize the tree
dtr_data = tree.export_graphviz(dtc, out_file=None, filled=True, rounded=False,
                      special_characters=True, max_depth=3,
                      feature_names=feat_tr.columns, class_names=["0", "1"])
graph = graphviz.Source(dtr_data)
graph

# %% [markdown]
# After removing the root node the model insuffient sleep and tuning the parameters the tree now scores 1.00 precision, 1.00 recall and 1.00 F1 on the training set—no longer perfect, but less overfit—and on the test set it achieves 0.93 precision, 0.86 recall and 0.90 F1, meaning almost every “improved” call is correct and it still catches most true improvements.
#
# New root split the first decision is Food_Insecurity_pct ≤ -0.036, sending counties with the least food insecurity down the “improved” branch and the rest toward “worsened.”
#
# Second split within the low-insecurity group, the model then checks Insufficient_Sleep_pct ≤ 0.013, further isolating improved counties before diving deeper.

# %%
# -- get predicted probabilities for the positive class (Worsened=1)
y_prob_te = dtc.predict_proba(feat_te)[:, 1]

# -- compute ROC metrics
fpr_te, tpr_te, _ = roc_curve(targ_te, y_prob_te)
roc_auc_te     = auc(fpr_te, tpr_te)

# -- plot the ROC curve
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(fpr_te, tpr_te, label=f'AUC = {roc_auc_te:.3f}')
ax.plot([0,1], [0,1], '--', label='Chance')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve – Test')
ax.legend(loc='lower right')
plt.show()

# %% [markdown]
#  an ROC (Receiver Operating Characteristic) curve for my classifier, I'm essentially looking at how the true positive rate (or sensitivity/recall) balances against the false positive rate as I change the decision threshold. By sweeping the cutoff from 0 to 1, I can see whether my model is consistently ranking the counties that have “worsened” conditions above those that have “improved,” independent of any specific probability threshold I choose. The Area Under the Curve (AUC) then compresses this entire performance into one number—where 0.5 is like random guessing and 1.0 indicates perfect separation between the classes.

# %% [markdown]
# The blue line rising well above the orange dashed “chance” line tells us the decision tree is substantially better than random.
#
# An AUC of 0.772 means there's about a 77 % chance a randomly chosen worsened county will get a higher predicted probability than a randomly chosen improved one.
#
# For example, at a false-positive rate of 0.2 (20 % of improved counties mis-flagged), we already achieve a true-positive rate of around 0.6 (60 % of worsened counties caught), reflecting a useful balance between sensitivity and specificity.
#
# Overall, the grid search cv tuned model trails yields slightly higher errors and captures a bit less variance in the target.

# %% [markdown]
# ---

# %% [markdown]
# ### **IV. Conclusions**

# %% [markdown]
# The problem statement is to uncover the key socio-economic predictors influencing county-level poor mental health and develop machine learning models to forecast the average number of poor mental health days per county. By analyzing how lifestyle changes correlate with mental health shifts, and provide data-driven insights that can inform public health initiatives.
#
# There are several socio-economic and health-behavior factors that drive county-level poor mental health days, including Insufficient Sleep, Food Insecurity, Adult Smoking, Unemployment, and Lack of Exercise Opportunities. Across our analyses, Insufficient_Sleep_pct and Food_Insecurity_pct consistently emerged as the strongest separators between counties whose mental health “improved” versus “worsened.”
#
# Our models successfully tackled two key objectives
#
# Classification results are i tried three ways to handle the 80/20 imbalance. SMOTE only balanced the training data but gave test precision = 0.61, recall = 0.67, F1 = 0.63. class weighting (5:1 “improved” weight) nudged the tree toward the minority class but test F1 stayed around 0.62. Hyperparameter tuning (max_depth=20, min_samples_leaf=15, min_samples_split=2) made the biggest jump: test precision = 0.94, recall = 0.87, F1 = 0.90, with AUC = 0.772.
# The tuned tree's first splits on Food_Insecurity_pct and Insufficient_Sleep_pct emerged as the clearest separators between counties likely to improve versus worsen.
#
#
# Regression model is predicting the exact number of poor mental health days per county using socio economic factors. A Random Forest regressor (max_depth=6, min_samples_leaf=20, min_samples_split=5, n_estimators=100) explained 71% of out-of-sample variance (R² = 0.71) with MSE = 0.11. Training performance was R² = 0.77 (MSE = 0.00), indicating modest overfitting. Feature-importance analysis confirmed Insufficient_Sleep_pct and Adult_Smoking_pct as the top predictors of mean poor mental health days.

# %% [markdown]
# **Limitations & assumptions:**
#
# Both models use only a 2019 and 023 county data so they miss year-to-year data betwen thse years and hide within-county differences.
#
# Survey lags, self-report error, and missing drivers (like funding changes or new policies) mean some variation goes unexplained.
#
# Treating counties independently ignores spillovers from neighboring regions, which can weaken prediction accuracy at borders.

# %% [markdown]
# ---
# ---
